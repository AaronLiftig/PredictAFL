# %% [markdown]
# # AFL Data Cleaning for Prediction Modeling
#
# ### Data found on Kaggle [here](https://www.kaggle.com/datasets/stoney71/aflstats)

# %%
import pandas as pd
import numpy as np

#Supresses scientific notation
pd.set_option('display.float_format', lambda x: '%.2f' % x)

import warnings
warnings.filterwarnings('ignore')

# %%
games_df = pd.read_csv("games.csv")
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024 entries, 0 to 2023
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameId         2024 non-null   object
#  1   year           2024 non-null   int64
#  2   round          2024 non-null   object
#  3   date           2024 non-null   object
#  4   venue          2024 non-null   object
#  5   startTime      2024 non-null   object
#  6   attendance     2024 non-null   int64
#  7   homeTeam       2024 non-null   object
#  8   homeTeamScore  2024 non-null   int64
#  9   awayTeam       2024 non-null   object
#  10  awayTeamScore  2024 non-null   int64
#  11  rainfall       1993 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 189.9+ KB

# %%
players_df = pd.read_csv("players.csv")
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495 entries, 0 to 1494
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   playerId     1495 non-null   int64
#  1   displayName  1495 non-null   object
#  2   height       1495 non-null   int64
#  3   weight       1495 non-null   int64
#  4   dob          1495 non-null   object
#  5   position     1495 non-null   object
#  6   origin       1491 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 81.9+ KB

# %%
stats_df = pd.read_csv("stats.csv")
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89470 entries, 0 to 89469
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameId                   89470 non-null  object
#  1   team                     89470 non-null  object
#  2   year                     89470 non-null  int64
#  3   round                    89470 non-null  object
#  4   playerId                 89470 non-null  int64
#  5   displayName              89470 non-null  object
#  6   gameNumber               89470 non-null  int64
#  7   Disposals                89470 non-null  int64
#  8   Kicks                    89470 non-null  int64
#  9   Marks                    89470 non-null  int64
#  10  Handballs                89470 non-null  int64
#  11  Goals                    89470 non-null  int64
#  12  Behinds                  89470 non-null  int64
#  13  Hit Outs                 89470 non-null  int64
#  14  Tackles                  89470 non-null  int64
#  15  Rebounds                 89470 non-null  int64
#  16  Inside 50s               89470 non-null  int64
#  17  Clearances               89470 non-null  int64
#  18  Clangers                 89470 non-null  int64
#  19  Frees                    89470 non-null  int64
#  20  Frees Against            89470 non-null  int64
#  21  Brownlow Votes           89470 non-null  int64
#  22  Contested Possessions    89470 non-null  int64
#  23  Uncontested Possessions  89470 non-null  int64
#  24  Contested Marks          89470 non-null  int64
#  25  Marks Inside 50          89470 non-null  int64
#  26  One Percenters           89470 non-null  int64
#  27  Bounces                  89470 non-null  int64
#  28  Goal Assists             89470 non-null  int64
#  29  % Played                 89470 non-null  int64
#  30  Subs                     45910 non-null  object
# dtypes: int64(26), object(5)
# memory usage: 21.2+ MB

# %% [markdown]
# ## Merging dataframes to create a dataframe broken down by player and game

# %%
df = stats_df.merge(games_df, how='left', on='gameId')\
             .merge(players_df, how='left', on='playerId')
df
# Out:
#           gameId              team  year_x round_x    playerId  \
# 0       2021R104          Adelaide    2021      R1  2021661124
# 1       2021R104          Adelaide    2021      R1  2012662083
# 2       2021R104          Adelaide    2021      R1  2020665315
# 3       2021R104          Adelaide    2021      R1  2018689604
# 4       2021R104          Adelaide    2021      R1  2018703883
# ...          ...               ...     ...     ...         ...
# 89465  2012R2309  Western Bulldogs    2012     R23  2011838967
# 89466  2012R2309  Western Bulldogs    2012     R23  2012833342
# 89467  2012R2309  Western Bulldogs    2012     R23  2012846405
# 89468  2012R2309  Western Bulldogs    2012     R23  2011872415
# 89469  2012R2309  Western Bulldogs    2012     R23  2009879614
#
#             displayName_x  gameNumber  Disposals  Kicks  Marks  ...  \
# 0              Berry, Sam           1          8      6      1  ...
# 1             Brown, Luke         168          5      2      0  ...
# 2           Butts, Jordon           3         10      5      3  ...
# 3             Doedee, Tom          31         13      9      4  ...
# 4         Frampton, Billy           9         14     10      8  ...
# ...                   ...         ...        ...    ...    ...  ...
# 89465  Skinner, Zephaniah           8          2      1      1  ...
# 89466         Smith, Clay          16         22     11      5  ...
# 89467      Talia, Michael           4         23     14      9  ...
# 89468       Wallis, Mitch          25         19      8      2  ...
# 89469        Wood, Easton          42         20     13     11  ...
#
#        homeTeamScore          awayTeam  awayTeamScore  rainfall  \
# 0                103           Geelong             91      0.00
# 1                103           Geelong             91      0.00
# 2                103           Geelong             91      0.00
# 3                103           Geelong             91      0.00
# 4                103           Geelong             91      0.00
# ...              ...               ...            ...       ...
# 89465            128  Western Bulldogs             61      0.00
# 89466            128  Western Bulldogs             61      0.00
# 89467            128  Western Bulldogs             61      0.00
# 89468            128  Western Bulldogs             61      0.00
# 89469            128  Western Bulldogs             61      0.00
#
#             displayName_y  height  weight          dob           position  \
# 0              Berry, Sam     181      81  12-Feb-2002  Midfield, Forward
# 1             Brown, Luke     181      81  22-Sep-1992           Defender
# 2           Butts, Jordon     198      83  31-Dec-1999           Defender
# 3             Doedee, Tom     188      88   1-Mar-1997           Defender
# 4         Frampton, Billy     200      90  20-Nov-1996            Forward
# ...                   ...     ...     ...          ...                ...
# 89465  Skinner, Zephaniah     189      79  27-Jun-1989            Forward
# 89466         Smith, Clay     181      85  11-May-1993            Forward
# 89467      Talia, Michael     194      94  11-Feb-1993           Defender
# 89468       Wallis, Mitch     186      85  24-Oct-1992            Forward
# 89469        Wood, Easton     187      86   4-Sep-1989           Defender
#
#                    origin
# 0         Gippsland Power
# 1                 Norwood
# 2      Murray Bushrangers
# 3         Geelong Falcons
# 4         South Fremantle
# ...                   ...
# 89465                   -
# 89466     Gippsland Power
# 89467      Calder Cannons
# 89468      Calder Cannons
# 89469          Camperdown
#
# [89470 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89470 entries, 0 to 89469
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameId                   89470 non-null  object
#  1   team                     89470 non-null  object
#  2   year_x                   89470 non-null  int64
#  3   round_x                  89470 non-null  object
#  4   playerId                 89470 non-null  int64
#  5   displayName_x            89470 non-null  object
#  6   gameNumber               89470 non-null  int64
#  7   Disposals                89470 non-null  int64
#  8   Kicks                    89470 non-null  int64
#  9   Marks                    89470 non-null  int64
#  10  Handballs                89470 non-null  int64
#  11  Goals                    89470 non-null  int64
#  12  Behinds                  89470 non-null  int64
#  13  Hit Outs                 89470 non-null  int64
#  14  Tackles                  89470 non-null  int64
#  15  Rebounds                 89470 non-null  int64
#  16  Inside 50s               89470 non-null  int64
#  17  Clearances               89470 non-null  int64
#  18  Clangers                 89470 non-null  int64
#  19  Frees                    89470 non-null  int64
#  20  Frees Against            89470 non-null  int64
#  21  Brownlow Votes           89470 non-null  int64
#  22  Contested Possessions    89470 non-null  int64
#  23  Uncontested Possessions  89470 non-null  int64
#  24  Contested Marks          89470 non-null  int64
#  25  Marks Inside 50          89470 non-null  int64
#  26  One Percenters           89470 non-null  int64
#  27  Bounces                  89470 non-null  int64
#  28  Goal Assists             89470 non-null  int64
#  29  % Played                 89470 non-null  int64
#  30  Subs                     45910 non-null  object
#  31  year_y                   89470 non-null  int64
#  32  round_y                  89470 non-null  object
#  33  date                     89470 non-null  object
#  34  venue                    89470 non-null  object
#  35  startTime                89470 non-null  object
#  36  attendance               89470 non-null  int64
#  37  homeTeam                 89470 non-null  object
#  38  homeTeamScore            89470 non-null  int64
#  39  awayTeam                 89470 non-null  object
#  40  awayTeamScore            89470 non-null  int64
#  41  rainfall                 88102 non-null  float64
#  42  displayName_y            89470 non-null  object
#  43  height                   89470 non-null  int64
#  44  weight                   89470 non-null  int64
#  45  dob                      89470 non-null  object
#  46  position                 89470 non-null  object
#  47  origin                   89428 non-null  object
# dtypes: float64(1), int64(32), object(15)
# memory usage: 33.4+ MB

# %% [markdown]
# ### Storing data for future use

# %%
year_list = sorted(list(df['year_x'].unique()))
year_list
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %% [markdown]
# ## Cleaning Data

# %%
df['rainfall'] = df['rainfall'].astype(float)
df['rainfall'].loc[df['rainfall'] > 0]
# Out:
# 69      4.20
# 70      4.20
# 71      4.20
# 72      4.20
# 73      4.20
#         ...
# 89443   1.60
# 89444   1.60
# 89445   1.60
# 89446   1.60
# 89447   1.60
# Name: rainfall, Length: 39430, dtype: float64

# %%
df['% Played'] = df['% Played'] / 100
df['% Played']
# Out:
# 0       0.80
# 1       0.23
# 2       0.93
# 3       0.84
# 4       0.90
#         ...
# 89465   0.28
# 89466   0.79
# 89467   0.88
# 89468   0.83
# 89469   0.89
# Name: % Played, Length: 89470, dtype: float64

# %% [markdown]
# ### Converting date and time objects to datetime

# %%
df = df[['playerId', 'height', 'weight', 'dob', 'position', 'gameId', 'team',
         'year_x', 'round_x', 'Disposals', 'Kicks', 'Marks', 'Handballs', 
         'Goals', 'Behinds', 'Hit Outs', 'Tackles', 'Rebounds', 'Inside 50s', 
         'Clearances', 'Clangers', 'Frees', 'Frees Against', 'Brownlow Votes', 
         'Contested Possessions', 'Uncontested Possessions', 'Contested Marks', 
         'Marks Inside 50', 'One Percenters', 'Bounces', 'Goal Assists', '% Played',
         'Subs', 'gameNumber',  'date', 'venue', 'startTime', 'attendance',
         'homeTeam', 'homeTeamScore', 'awayTeam', 'awayTeamScore', 'rainfall']]

df.rename({'year_x': 'year', 'round_x': 'round'}, axis=1, inplace=True)

# %% [markdown]
# #### Changing month abbreviation to numerical value

# %%
date_dict = {'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06',
             'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'}

# %%
dob = df['dob'].str.split('-', expand=True)
dob[1] = dob[1].replace(date_dict)
df['dob'] = dob.apply(lambda row: '-'.join(row.values.astype(str)), axis=1)
df['dob']
# Out:
# 0        12-02-2002
# 1        22-09-1992
# 2        31-12-1999
# 3         1-03-1997
# 4        20-11-1996
#             ...
# 89465    27-06-1989
# 89466    11-05-1993
# 89467    11-02-1993
# 89468    24-10-1992
# 89469     4-09-1989
# Name: dob, Length: 89470, dtype: object

# %%
date = df['date'].str.split('-', expand=True)
date[1] = date[1].replace(date_dict)
df['date'] = date.apply(lambda row: '-'.join(row.values.astype(str)), axis=1)
df['date']
# Out:
# 0        20-03-2021
# 1        20-03-2021
# 2        20-03-2021
# 3        20-03-2021
# 4        20-03-2021
#             ...
# 89465    02-09-2012
# 89466    02-09-2012
# 89467    02-09-2012
# 89468    02-09-2012
# 89469    02-09-2012
# Name: date, Length: 89470, dtype: object

# %%
df['dob'] = pd.to_datetime(df['dob'], format='%d'+'-'+'%m'+'-'+'%Y')
df['date'] = pd.to_datetime(df['date'], format='%d'+'-'+'%m'+'-'+'%Y')

# %% [markdown]
# ### Converting startTime to Start Time Hour and Start Time Minute

# %%
df['Start Time Hour'] = pd.to_datetime(df['startTime'], format= '%I:%M %p').dt.hour
df['Start Time Minute'] = pd.to_datetime(df['startTime'], format= '%I:%M %p').dt.minute

df.drop('startTime', axis=1, inplace=True)
df[['Start Time Hour', 'Start Time Minute']]
# Out:
#        Start Time Hour  Start Time Minute
# 0                   16                  5
# 1                   16                  5
# 2                   16                  5
# 3                   16                  5
# 4                   16                  5
# ...                ...                ...
# 89465               16                 40
# 89466               16                 40
# 89467               16                 40
# 89468               16                 40
# 89469               16                 40
#
# [89470 rows x 2 columns]

# %% [markdown]
# ### Fixing 'round' column by making Finals rounds numerical

# %%
round_list = {'QF': '24', 'SF': '25', 'PF': '26', 'GF': '27', 'EF': '24'}
df['round'] = df['round'].replace(round_list)
df['round'] = df['round'].str.replace('R', '').astype(int)

# %% [markdown]
# ### Adding 'year+1' column for future indexing

# %%
df['year+1'] = df['year'] + 1
df['year+1']
# Out:
# 0        2022
# 1        2022
# 2        2022
# 3        2022
# 4        2022
#          ...
# 89465    2013
# 89466    2013
# 89467    2013
# 89468    2013
# 89469    2013
# Name: year+1, Length: 89470, dtype: int64

# %% [markdown]
# ### Constructing index

# %%
df = df.set_index(['year','round'], append=True)

# %% [markdown]
# ## Feature Creation
# ### Age

# %%
df.insert(2, 'Age', (df['date'] - df['dob']) / np.timedelta64(1,'Y'))

df.drop('dob', axis=1, inplace=True)

# %% [markdown]
# ### Total Points Scored

# %%
df['Total Points Scored'] = df['Goals'] * 6 + df['Behinds']
df['Total Points Scored']
# Out:
#        year  round
# 0      2021  1         1
# 1      2021  1         0
# 2      2021  1         0
# 3      2021  1         0
# 4      2021  1        14
#                       ..
# 89465  2012  23        0
# 89466  2012  23        0
# 89467  2012  23        0
# 89468  2012  23        6
# 89469  2012  23        0
# Name: Total Points Scored, Length: 89470, dtype: int64

# %% [markdown]
# ### Is Home Team

# %%
df['Is Home Team'] = np.where(df['team'] == df['homeTeam'], 1, 0)
df['Is Home Team']
# Out:
#        year  round
# 0      2021  1        1
# 1      2021  1        1
# 2      2021  1        1
# 3      2021  1        1
# 4      2021  1        1
#                      ..
# 89465  2012  23       0
# 89466  2012  23       0
# 89467  2012  23       0
# 89468  2012  23       0
# 89469  2012  23       0
# Name: Is Home Team, Length: 89470, dtype: int32

# %% [markdown]
# ### Opponent Team

# %%
df['Opponent Team'] = np.where(df['team'] == df['homeTeam'], df['awayTeam'], df['homeTeam'])

df.drop('awayTeam', axis=1, inplace=True)

# %% [markdown]
# ### Player Team Score and Opponent Team Score

# %%
df['Player Team Score'] = np.where(df['team'] == df['homeTeam'], df['homeTeamScore'], df['awayTeamScore'])
df['Opponent Team Score'] = np.where(df['team'] == df['homeTeam'], df['awayTeamScore'], df['homeTeamScore'])

# %% [markdown]
# ### Score Margin (from the perspective of each player)

# %%
df['Margin'] = np.where(df['Is Home Team'] == 1,
                        df['homeTeamScore'] - df['awayTeamScore'],
                        df['awayTeamScore'] - df['homeTeamScore'])
df['Margin']
# Out:
#        year  round
# 0      2021  1        12
# 1      2021  1        12
# 2      2021  1        12
# 3      2021  1        12
# 4      2021  1        12
#                       ..
# 89465  2012  23      -67
# 89466  2012  23      -67
# 89467  2012  23      -67
# 89468  2012  23      -67
# 89469  2012  23      -67
# Name: Margin, Length: 89470, dtype: int64

# %% [markdown]
# ### Game Result

# %%
conditions = [df['Margin'] > 0, df['Margin'] == 0, df['Margin'] < 0]
choices = [1, .5, 0]
df['Game Result'] = np.select(conditions, choices)
df['Game Result']
# Out:
#        year  round
# 0      2021  1       1.00
# 1      2021  1       1.00
# 2      2021  1       1.00
# 3      2021  1       1.00
# 4      2021  1       1.00
#                      ...
# 89465  2012  23      0.00
# 89466  2012  23      0.00
# 89467  2012  23      0.00
# 89468  2012  23      0.00
# 89469  2012  23      0.00
# Name: Game Result, Length: 89470, dtype: float64

# %% [markdown]
# ### Month

# %%
df['Month'] = df['date'].dt.month

# %% [markdown]
# ### Day of year

# %%
df['Day of Year'] = df['date'].dt.dayofyear

# %% [markdown]
# ### Weekday

# %%
df['Weekday'] = df['date'].dt.weekday

# %%
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# ### Spliting 'position' into multiple columns

# %%
df['position'].unique()
# Out:
# array(['Midfield, Forward', 'Defender', 'Forward', 'Midfield', 'Ruck',
#        'Defender, Midfield', 'Forward, Ruck', 'Defender, Forward',
#        'Defender, Ruck', 'Midfield, Ruck'], dtype=object)

# %%
position_list = ['Midfield', 'Forward', 'Defender', 'Ruck']

for pos in position_list:
    df[f'{pos}'] = np.where(df['position'].str.contains(pos), 1, 0)
    
df.drop('position', axis=1, inplace=True)

df[position_list].sum()
# Out:
# Midfield    31786
# Forward     33602
# Defender    34426
# Ruck         5850
# dtype: int64

# %% [markdown]
# ### Shifting (offsetting) and aggregating features

# %%
df_final = df.copy()

# %%
shift_columns = ['Disposals', 'Kicks', 'Marks', 'Handballs', 'Goals', 'Behinds', 'Hit Outs',
                 'Tackles', 'Rebounds', 'Inside 50s', 'Clearances', 'Clangers', 'Frees',
                 'Frees Against', 'Brownlow Votes', 'Contested Possessions', 'Uncontested Possessions',
                 'Contested Marks', 'Marks Inside 50', 'One Percenters', 'Bounces', 'Goal Assists',
                 '% Played', 'Subs', 'venue', 'Player Team Score', 'Opponent Team Score', 'rainfall', 
                 'Margin', 'Total Points Scored', 'Game Result', 'gameNumber', 'Start Time Hour', 
                 'Start Time Minute', 'Month', 'Weekday', 'Day of Year', 'team', 'Opponent Team']

average_and_sum_columns = [col for col in shift_columns if col not in ['venue', 'rainfall', 'Subs', 'Opponent Team',
                                                                       'team', 'Start Time Hour', 'Start Time Minute',
                                                                       'Month', 'Weekday', 'Day of Year']]

# %%
def offset_function(dataframe, column_list, year_list):
    frame = None
    for col in column_list:
        for i in range(1,6): # Shifting back 1 to 5 games
            for n, year in enumerate(year_list):
                year_df = dataframe.xs(year, level=1, drop_level=False)
                year_df = year_df.sort_index(level=['year', 'round'])
                df_group = year_df.groupby('playerId')[col]
                df_shift = df_group.shift(i)
                if n != 0:
                    df = pd.concat([df, df_shift])
                else:
                    df = df_shift
                    
            df = df.rename(f'{col}_shift_{i}')
            if frame is None:
                frame = df
            else:
                frame = pd.concat((frame, df), axis=1)
    return frame

# %%
offset_df = offset_function(df, shift_columns, year_list)
df_final = pd.concat((df_final, offset_df), axis=1)
offset_df
# Out:
#                   Disposals_shift_1  Disposals_shift_2  Disposals_shift_3  \
#       year round
# 80362 2012 1                    NaN                NaN                NaN
# 80363 2012 1                    NaN                NaN                NaN
# 80364 2012 1                    NaN                NaN                NaN
# 80365 2012 1                    NaN                NaN                NaN
# 80366 2012 1                    NaN                NaN                NaN
# ...                             ...                ...                ...
# 9517  2021 27                 23.00              10.00              28.00
# 9518  2021 27                  6.00              10.00              10.00
# 9519  2021 27                  4.00              12.00              10.00
# 9520  2021 27                 19.00              13.00              13.00
# 9521  2021 27                 16.00              12.00              10.00
#
#                   Disposals_shift_4  Disposals_shift_5  Kicks_shift_1  \
#       year round
# 80362 2012 1                    NaN                NaN            NaN
# 80363 2012 1                    NaN                NaN            NaN
# 80364 2012 1                    NaN                NaN            NaN
# 80365 2012 1                    NaN                NaN            NaN
# 80366 2012 1                    NaN                NaN            NaN
# ...                             ...                ...            ...
# 9517  2021 27                 20.00              15.00          13.00
# 9518  2021 27                 14.00               9.00           2.00
# 9519  2021 27                  7.00              14.00           3.00
# 9520  2021 27                 13.00              16.00          16.00
# 9521  2021 27                 13.00              13.00          12.00
#
#                   Kicks_shift_2  Kicks_shift_3  Kicks_shift_4  Kicks_shift_5  \
#       year round
# 80362 2012 1                NaN            NaN            NaN            NaN
# 80363 2012 1                NaN            NaN            NaN            NaN
# 80364 2012 1                NaN            NaN            NaN            NaN
# 80365 2012 1                NaN            NaN            NaN            NaN
# 80366 2012 1                NaN            NaN            NaN            NaN
# ...                         ...            ...            ...            ...
# 9517  2021 27              2.00          13.00          10.00           2.00
# 9518  2021 27              5.00           6.00           8.00           4.00
# 9519  2021 27              9.00           6.00           5.00          11.00
# 9520  2021 27             10.00           9.00           8.00           9.00
# 9521  2021 27              9.00           7.00           6.00           9.00
#
#                   ...      team_shift_1      team_shift_2      team_shift_3  \
#       year round  ...
# 80362 2012 1      ...               NaN               NaN               NaN
# 80363 2012 1      ...               NaN               NaN               NaN
# 80364 2012 1      ...               NaN               NaN               NaN
# 80365 2012 1      ...               NaN               NaN               NaN
# 80366 2012 1      ...               NaN               NaN               NaN
# ...               ...               ...               ...               ...
# 9517  2021 27     ...  Western Bulldogs  Western Bulldogs  Western Bulldogs
# 9518  2021 27     ...  Western Bulldogs  Western Bulldogs  Western Bulldogs
# 9519  2021 27     ...  Western Bulldogs  Western Bulldogs  Western Bulldogs
# 9520  2021 27     ...  Western Bulldogs  Western Bulldogs  Western Bulldogs
# 9521  2021 27     ...  Western Bulldogs  Western Bulldogs  Western Bulldogs
#
#                       team_shift_4      team_shift_5  Opponent Team_shift_1  \
#       year round
# 80362 2012 1                   NaN               NaN                    NaN
# 80363 2012 1                   NaN               NaN                    NaN
# 80364 2012 1                   NaN               NaN                    NaN
# 80365 2012 1                   NaN               NaN                    NaN
# 80366 2012 1                   NaN               NaN                    NaN
# ...                            ...               ...                    ...
# 9517  2021 27     Western Bulldogs  Western Bulldogs          Port Adelaide
# 9518  2021 27     Western Bulldogs  Western Bulldogs          Port Adelaide
# 9519  2021 27     Western Bulldogs  Western Bulldogs         Brisbane Lions
# 9520  2021 27     Western Bulldogs  Western Bulldogs          Port Adelaide
# 9521  2021 27     Western Bulldogs  Western Bulldogs          Port Adelaide
#
#                   Opponent Team_shift_2  Opponent Team_shift_3  \
#       year round
# 80362 2012 1                        NaN                    NaN
# 80363 2012 1                        NaN                    NaN
# 80364 2012 1                        NaN                    NaN
# 80365 2012 1                        NaN                    NaN
# 80366 2012 1                        NaN                    NaN
# ...                                 ...                    ...
# 9517  2021 27            Brisbane Lions               Essendon
# 9518  2021 27            Brisbane Lions               Essendon
# 9519  2021 27                  Essendon          Port Adelaide
# 9520  2021 27            Brisbane Lions               Essendon
# 9521  2021 27            Brisbane Lions               Essendon
#
#                   Opponent Team_shift_4  Opponent Team_shift_5
#       year round
# 80362 2012 1                        NaN                    NaN
# 80363 2012 1                        NaN                    NaN
# 80364 2012 1                        NaN                    NaN
# 80365 2012 1                        NaN                    NaN
# 80366 2012 1                        NaN                    NaN
# ...                                 ...                    ...
# 9517  2021 27             Port Adelaide               Hawthorn
# 9518  2021 27             Port Adelaide               Hawthorn
# 9519  2021 27                  Hawthorn               Adelaide
# 9520  2021 27             Port Adelaide               Hawthorn
# 9521  2021 27             Port Adelaide               Hawthorn
#
# [89470 rows x 195 columns]

# %%
def window_function(dataframe, column_list, year_list):
    frame = None
    for col in column_list:
        for window_func in ('boxcar', 'exponential', 'triang'):
            for func in ('sum', 'mean'):
                for i in (3, 5): # Rolling window size
                    for n, year in enumerate(year_list):
                        year_df = dataframe.xs(year, level=1, drop_level=False)
                        year_df = year_df.sort_index(level=['year', 'round'])
                        df_group = year_df.groupby('playerId')[col]
                        df_shift = df_group.shift()
                        df_rolling = df_shift.rolling(i, win_type=window_func, min_periods=1)
                        if func == 'sum':
                            df_rolling = df_rolling.sum()
                        elif func == 'mean':
                            df_rolling = df_rolling.mean()
                        
                        if n != 0:
                            df = pd.concat([df, df_rolling])
                        else:
                            df = df_rolling

                    df = df.rename(f'{col}_{window_func}_{func}_{i}')
                    if frame is None:
                        frame = df
                    else:
                        frame = pd.concat((frame, df), axis=1)
    #frame = frame.reset_index('playerId', drop=True)
    return frame

# %%
window_df = window_function(df, average_and_sum_columns, year_list)
df_final = pd.concat((df_final, window_df), axis=1)
window_df
# Out:
#                   Disposals_boxcar_sum_3  Disposals_boxcar_sum_5  \
#       year round
# 80362 2012 1                         NaN                     NaN
# 80363 2012 1                         NaN                     NaN
# 80364 2012 1                         NaN                     NaN
# 80365 2012 1                         NaN                     NaN
# 80366 2012 1                         NaN                     NaN
# ...                                  ...                     ...
# 9517  2021 27                      61.00                   82.00
# 9518  2021 27                      44.00                   77.00
# 9519  2021 27                      33.00                   71.00
# 9520  2021 27                      29.00                   67.00
# 9521  2021 27                      39.00                   68.00
#
#                   Disposals_boxcar_mean_3  Disposals_boxcar_mean_5  \
#       year round
# 80362 2012 1                          NaN                      NaN
# 80363 2012 1                          NaN                      NaN
# 80364 2012 1                          NaN                      NaN
# 80365 2012 1                          NaN                      NaN
# 80366 2012 1                          NaN                      NaN
# ...                                   ...                      ...
# 9517  2021 27                       20.33                    16.40
# 9518  2021 27                       14.67                    15.40
# 9519  2021 27                       11.00                    14.20
# 9520  2021 27                        9.67                    13.40
# 9521  2021 27                       13.00                    13.60
#
#                   Disposals_exponential_sum_3  Disposals_exponential_sum_5  \
#       year round
# 80362 2012 1                              NaN                          NaN
# 80363 2012 1                              NaN                          NaN
# 80364 2012 1                              NaN                          NaN
# 80365 2012 1                              NaN                          NaN
# 80366 2012 1                              NaN                          NaN
# ...                                       ...                          ...
# 9517  2021 27                           31.92                        36.80
# 9518  2021 27                           30.73                        34.09
# 9519  2021 27                           15.93                        34.38
# 9520  2021 27                           13.20                        20.53
# 9521  2021 27                           26.36                        18.48
#
#                   Disposals_exponential_mean_3  Disposals_exponential_mean_5  \
#       year round
# 80362 2012 1                               NaN                           NaN
# 80363 2012 1                               NaN                           NaN
# 80364 2012 1                               NaN                           NaN
# 80365 2012 1                               NaN                           NaN
# 80366 2012 1                               NaN                           NaN
# ...                                        ...                           ...
# 9517  2021 27                            18.39                         18.34
# 9518  2021 27                            17.70                         16.99
# 9519  2021 27                             9.18                         17.13
# 9520  2021 27                             7.60                         10.23
# 9521  2021 27                            15.19                          9.21
#
#                   Disposals_triang_sum_3  Disposals_triang_sum_5  ...  \
#       year round                                                  ...
# 80362 2012 1                         NaN                     NaN  ...
# 80363 2012 1                         NaN                     NaN  ...
# 80364 2012 1                         NaN                     NaN  ...
# 80365 2012 1                         NaN                     NaN  ...
# 80366 2012 1                         NaN                     NaN  ...
# ...                                  ...                     ...  ...
# 9517  2021 27                      38.00                   51.00  ...
# 9518  2021 27                      33.50                   51.00  ...
# 9519  2021 27                      19.50                   46.00  ...
# 9520  2021 27                      16.50                   35.33  ...
# 9521  2021 27                      29.00                   33.67  ...
#
#                   gameNumber_boxcar_mean_3  gameNumber_boxcar_mean_5  \
#       year round
# 80362 2012 1                           NaN                       NaN
# 80363 2012 1                           NaN                       NaN
# 80364 2012 1                           NaN                       NaN
# 80365 2012 1                           NaN                       NaN
# 80366 2012 1                           NaN                       NaN
# ...                                    ...                       ...
# 9517  2021 27                        97.00                     86.40
# 9518  2021 27                        82.33                     75.40
# 9519  2021 27                        76.33                     66.20
# 9520  2021 27                        40.33                     69.20
# 9521  2021 27                        95.33                     99.40
#
#                   gameNumber_exponential_sum_3  gameNumber_exponential_sum_5  \
#       year round
# 80362 2012 1                               NaN                           NaN
# 80363 2012 1                               NaN                           NaN
# 80364 2012 1                               NaN                           NaN
# 80365 2012 1                               NaN                           NaN
# 80366 2012 1                               NaN                           NaN
# ...                                        ...                           ...
# 9517  2021 27                           129.81                        138.79
# 9518  2021 27                           210.34                        141.45
# 9519  2021 27                            98.15                        221.71
# 9520  2021 27                            55.89                        113.99
# 9521  2021 27                           156.42                        106.78
#
#                   gameNumber_exponential_mean_3  \
#       year round
# 80362 2012 1                                NaN
# 80363 2012 1                                NaN
# 80364 2012 1                                NaN
# 80365 2012 1                                NaN
# 80366 2012 1                                NaN
# ...                                         ...
# 9517  2021 27                             74.79
# 9518  2021 27                            121.18
# 9519  2021 27                             56.55
# 9520  2021 27                             32.20
# 9521  2021 27                             90.11
#
#                   gameNumber_exponential_mean_5  gameNumber_triang_sum_3  \
#       year round
# 80362 2012 1                                NaN                      NaN
# 80363 2012 1                                NaN                      NaN
# 80364 2012 1                                NaN                      NaN
# 80365 2012 1                                NaN                      NaN
# 80366 2012 1                                NaN                      NaN
# ...                                         ...                      ...
# 9517  2021 27                             69.17                   163.50
# 9518  2021 27                             70.50                   218.00
# 9519  2021 27                            110.50                   125.50
# 9520  2021 27                             56.81                    69.50
# 9521  2021 27                             53.22                   183.50
#
#                   gameNumber_triang_sum_5  gameNumber_triang_mean_3  \
#       year round
# 80362 2012 1                          NaN                       NaN
# 80363 2012 1                          NaN                       NaN
# 80364 2012 1                          NaN                       NaN
# 80365 2012 1                          NaN                       NaN
# 80366 2012 1                          NaN                       NaN
# ...                                   ...                       ...
# 9517  2021 27                      221.33                     81.75
# 9518  2021 27                      234.67                    109.00
# 9519  2021 27                      255.67                     62.75
# 9520  2021 27                      199.00                     34.75
# 9521  2021 27                      212.00                     91.75
#
#                   gameNumber_triang_mean_5
#       year round
# 80362 2012 1                           NaN
# 80363 2012 1                           NaN
# 80364 2012 1                           NaN
# 80365 2012 1                           NaN
# 80366 2012 1                           NaN
# ...                                    ...
# 9517  2021 27                        73.78
# 9518  2021 27                        78.22
# 9519  2021 27                        85.22
# 9520  2021 27                        66.33
# 9521  2021 27                        70.67
#
# [89470 rows x 348 columns]

# %%
def current_year_cumulative_function(dataframe, column_list, year_list):
    frame = None
    for col in column_list:
        for func in ['sum', 'max', 'min']:
            for n, year in enumerate(year_list):
                year_df = dataframe.xs(year, level=1, drop_level=False)
                year_df = year_df.set_index('playerId', append=True)
                year_df = year_df.sort_index(level=['year', 'round'])
                df_group = year_df.groupby('playerId')[col]
                if func == 'sum':
                    df_cum = df_group.cumsum()
                elif func == 'max':
                    df_cum = df_group.cummax()
                elif func == 'min':
                    df_cum = df_group.cummin()
                
                df_group_cum = df_cum.groupby('playerId')
                df_shift = df_group_cum.shift()
                    
                if n != 0:
                    df = pd.concat([df, df_shift])
                else:
                    df = df_shift
            df = df.rename(f'{col}_cumulative_{func}')
            if frame is None:
                frame = df
            else:
                frame = pd.concat((frame, df), axis=1)
    frame = frame.reset_index('playerId', drop=True)
    return frame

# %%
cumulative_df = current_year_cumulative_function(df, average_and_sum_columns, year_list)
df_final = pd.concat((df_final, cumulative_df), axis=1)
cumulative_df
# Out:
#                   Disposals_cumulative_sum  Disposals_cumulative_max  \
#       year round
# 80362 2012 1                           NaN                       NaN
# 80363 2012 1                           NaN                       NaN
# 80364 2012 1                           NaN                       NaN
# 80365 2012 1                           NaN                       NaN
# 80366 2012 1                           NaN                       NaN
# ...                                    ...                       ...
# 9517  2021 27                       368.00                     35.00
# 9518  2021 27                        96.00                     14.00
# 9519  2021 27                       153.00                     14.00
# 9520  2021 27                       370.00                     28.00
# 9521  2021 27                       167.00                     22.00
#
#                   Disposals_cumulative_min  Kicks_cumulative_sum  \
#       year round
# 80362 2012 1                           NaN                   NaN
# 80363 2012 1                           NaN                   NaN
# 80364 2012 1                           NaN                   NaN
# 80365 2012 1                           NaN                   NaN
# 80366 2012 1                           NaN                   NaN
# ...                                    ...                   ...
# 9517  2021 27                        10.00                175.00
# 9518  2021 27                         6.00                 46.00
# 9519  2021 27                         4.00                117.00
# 9520  2021 27                        11.00                239.00
# 9521  2021 27                         1.00                107.00
#
#                   Kicks_cumulative_max  Kicks_cumulative_min  \
#       year round
# 80362 2012 1                       NaN                   NaN
# 80363 2012 1                       NaN                   NaN
# 80364 2012 1                       NaN                   NaN
# 80365 2012 1                       NaN                   NaN
# 80366 2012 1                       NaN                   NaN
# ...                                ...                   ...
# 9517  2021 27                    17.00                  2.00
# 9518  2021 27                     8.00                  2.00
# 9519  2021 27                    12.00                  3.00
# 9520  2021 27                    21.00                  6.00
# 9521  2021 27                    12.00                  1.00
#
#                   Marks_cumulative_sum  Marks_cumulative_max  \
#       year round
# 80362 2012 1                       NaN                   NaN
# 80363 2012 1                       NaN                   NaN
# 80364 2012 1                       NaN                   NaN
# 80365 2012 1                       NaN                   NaN
# 80366 2012 1                       NaN                   NaN
# ...                                ...                   ...
# 9517  2021 27                    47.00                  7.00
# 9518  2021 27                    24.00                  6.00
# 9519  2021 27                    47.00                  7.00
# 9520  2021 27                   101.00                  8.00
# 9521  2021 27                    66.00                 11.00
#
#                   Marks_cumulative_min  Handballs_cumulative_sum  ...  \
#       year round                                                  ...
# 80362 2012 1                       NaN                       NaN  ...
# 80363 2012 1                       NaN                       NaN  ...
# 80364 2012 1                       NaN                       NaN  ...
# 80365 2012 1                       NaN                       NaN  ...
# 80366 2012 1                       NaN                       NaN  ...
# ...                                ...                       ...  ...
# 9517  2021 27                     0.00                    193.00  ...
# 9518  2021 27                     0.00                     50.00  ...
# 9519  2021 27                     0.00                     36.00  ...
# 9520  2021 27                     1.00                    131.00  ...
# 9521  2021 27                     0.00                     60.00  ...
#
#                   Margin_cumulative_min  Total Points Scored_cumulative_sum  \
#       year round
# 80362 2012 1                        NaN                                 NaN
# 80363 2012 1                        NaN                                 NaN
# 80364 2012 1                        NaN                                 NaN
# 80365 2012 1                        NaN                                 NaN
# 80366 2012 1                        NaN                                 NaN
# ...                                 ...                                 ...
# 9517  2021 27                    -27.00                               69.00
# 9518  2021 27                    -27.00                               44.00
# 9519  2021 27                    -28.00                              169.00
# 9520  2021 27                    -28.00                                8.00
# 9521  2021 27                    -27.00                               12.00
#
#                   Total Points Scored_cumulative_max  \
#       year round
# 80362 2012 1                                     NaN
# 80363 2012 1                                     NaN
# 80364 2012 1                                     NaN
# 80365 2012 1                                     NaN
# 80366 2012 1                                     NaN
# ...                                              ...
# 9517  2021 27                                  19.00
# 9518  2021 27                                  12.00
# 9519  2021 27                                  25.00
# 9520  2021 27                                   6.00
# 9521  2021 27                                   6.00
#
#                   Total Points Scored_cumulative_min  \
#       year round
# 80362 2012 1                                     NaN
# 80363 2012 1                                     NaN
# 80364 2012 1                                     NaN
# 80365 2012 1                                     NaN
# 80366 2012 1                                     NaN
# ...                                              ...
# 9517  2021 27                                   0.00
# 9518  2021 27                                   0.00
# 9519  2021 27                                   1.00
# 9520  2021 27                                   0.00
# 9521  2021 27                                   0.00
#
#                   Game Result_cumulative_sum  Game Result_cumulative_max  \
#       year round
# 80362 2012 1                             NaN                         NaN
# 80363 2012 1                             NaN                         NaN
# 80364 2012 1                             NaN                         NaN
# 80365 2012 1                             NaN                         NaN
# 80366 2012 1                             NaN                         NaN
# ...                                      ...                         ...
# 9517  2021 27                          12.00                        1.00
# 9518  2021 27                           8.00                        1.00
# 9519  2021 27                          10.00                        1.00
# 9520  2021 27                          16.00                        1.00
# 9521  2021 27                          10.00                        1.00
#
#                   Game Result_cumulative_min  gameNumber_cumulative_sum  \
#       year round
# 80362 2012 1                             NaN                        NaN
# 80363 2012 1                             NaN                        NaN
# 80364 2012 1                             NaN                        NaN
# 80365 2012 1                             NaN                        NaN
# 80366 2012 1                             NaN                        NaN
# ...                                      ...                        ...
# 9517  2021 27                           0.00                    2904.00
# 9518  2021 27                           0.00                     175.00
# 9519  2021 27                           0.00                     165.00
# 9520  2021 27                           0.00                    1551.00
# 9521  2021 27                           0.00                    2527.00
#
#                   gameNumber_cumulative_max  gameNumber_cumulative_min
#       year round
# 80362 2012 1                            NaN                        NaN
# 80363 2012 1                            NaN                        NaN
# 80364 2012 1                            NaN                        NaN
# 80365 2012 1                            NaN                        NaN
# 80366 2012 1                            NaN                        NaN
# ...                                     ...                        ...
# 9517  2021 27                        189.00                     174.00
# 9518  2021 27                         22.00                      13.00
# 9519  2021 27                         18.00                       4.00
# 9520  2021 27                         81.00                      60.00
# 9521  2021 27                        187.00                     174.00
#
# [89470 rows x 87 columns]

# %%
def previous_year_cumulative_function(dataframe, column_list, year_list):
    df = dataframe.reset_index(['year', 'round'])
    df = df.set_index(['playerId', 'year+1'])
    df_sum = df.groupby(['playerId', 'year+1'])[average_and_sum_columns].sum()
    df_mean = df.groupby(['playerId', 'year+1'])[average_and_sum_columns].mean()
    return df_sum, df_mean

# %%
df_sum, df_mean = previous_year_cumulative_function(df, average_and_sum_columns, year_list)

# %%
df_final = df_final.reset_index(['year', 'round'])

# %%
df_final = df_final.merge(df_sum, how='left', left_on=['playerId', 'year'],
                          right_on=['playerId', 'year+1'], suffixes=('', '_prevous_year_sum'))
df_sum
# Out:
#                     Disposals  Kicks  Marks  Handballs  Goals  Behinds  \
# playerId    year+1
# 1993707514  2013          289    244     88         45      1        2
#             2014          198    151     63         47      0        0
#             2015          279    198    103         81      1        0
#             2016          116     80     35         36      1        1
# 1996722607  2013          520    285     99        235     35        9
# ...                       ...    ...    ...        ...    ...      ...
# 20151001643 2018          265    139     60        126     14        8
#             2019          338    232     92        106     48       22
#             2020          285    204     81         81     34       22
#             2021          135     86     26         49     14       12
#             2022          420    251    108        169     23       23
#
#                     Hit Outs  Tackles  Rebounds  Inside 50s  ...  \
# playerId    year+1                                           ...
# 1993707514  2013           0       20        89          20  ...
#             2014           0       14        67           8  ...
#             2015           0       11        60          21  ...
#             2016           0        6        36           5  ...
# 1996722607  2013           0       47        30          83  ...
# ...                      ...      ...       ...         ...  ...
# 20151001643 2018           1       47        10          46  ...
#             2019           0       48         9          72  ...
#             2020           0       35         3          61  ...
#             2021           0       12         5          28  ...
#             2022           0       39        24          70  ...
#
#                     One Percenters  Bounces  Goal Assists  % Played  \
# playerId    year+1
# 1993707514  2013               110        0             0     16.00
#             2014                65        2             1     11.55
#             2015                96        0             1     12.79
#             2016                50        0             1      5.80
# 1996722607  2013                28       49            18     20.11
# ...                            ...      ...           ...       ...
# 20151001643 2018                14        4             9     11.41
#             2019                21        9            17     17.07
#             2020                13        7            13     13.21
#             2021                11        2             4      8.70
#             2022                20        0            13     16.68
#
#                     Player Team Score  Opponent Team Score  Margin  \
# playerId    year+1
# 1993707514  2013                 1743                 1727      16
#             2014                 1259                 1152     107
#             2015                 1277                 1120     157
#             2016                  573                  548      25
# 1996722607  2013                 2425                 2259     166
# ...                               ...                  ...     ...
# 20151001643 2018                 1296                 1285      11
#             2019                 1962                 1531     431
#             2020                 1374                 1291      83
#             2021                  593                  553      40
#             2022                 1393                 1618    -225
#
#                     Total Points Scored  Game Result  gameNumber
# playerId    year+1
# 1993707514  2013                      8        10.00        6417
#             2014                      0         8.00        4836
#             2015                      6         9.00        5790
#             2016                      7         3.00        2779
# 1996722607  2013                    219        14.00        7705
# ...                                 ...          ...         ...
# 20151001643 2018                     92         6.50         609
#             2019                    310        16.00        1281
#             2020                    226        10.00        1360
#             2021                     96         5.50         935
#             2022                    161         6.00        2170
#
# [6634 rows x 29 columns]

# %%
df_final = df_final.merge(df_mean, how='left', left_on=['playerId', 'year'],
                          right_on=['playerId', 'year+1'], suffixes=('', '_prevous_year_mean'))
df_mean
# Out:
#                     Disposals  Kicks  Marks  Handballs  Goals  Behinds  \
# playerId    year+1
# 1993707514  2013        16.06  13.56   4.89       2.50   0.06     0.11
#             2014        15.23  11.62   4.85       3.62   0.00     0.00
#             2015        18.60  13.20   6.87       5.40   0.07     0.00
#             2016        16.57  11.43   5.00       5.14   0.14     0.14
# 1996722607  2013        22.61  12.39   4.30      10.22   1.52     0.39
# ...                       ...    ...    ...        ...    ...      ...
# 20151001643 2018        18.93   9.93   4.29       9.00   1.00     0.57
#             2019        16.10  11.05   4.38       5.05   2.29     1.05
#             2020        16.76  12.00   4.76       4.76   2.00     1.29
#             2021        13.50   8.60   2.60       4.90   1.40     1.20
#             2022        21.00  12.55   5.40       8.45   1.15     1.15
#
#                     Hit Outs  Tackles  Rebounds  Inside 50s  ...  \
# playerId    year+1                                           ...
# 1993707514  2013        0.00     1.11      4.94        1.11  ...
#             2014        0.00     1.08      5.15        0.62  ...
#             2015        0.00     0.73      4.00        1.40  ...
#             2016        0.00     0.86      5.14        0.71  ...
# 1996722607  2013        0.00     2.04      1.30        3.61  ...
# ...                      ...      ...       ...         ...  ...
# 20151001643 2018        0.07     3.36      0.71        3.29  ...
#             2019        0.00     2.29      0.43        3.43  ...
#             2020        0.00     2.06      0.18        3.59  ...
#             2021        0.00     1.20      0.50        2.80  ...
#             2022        0.00     1.95      1.20        3.50  ...
#
#                     One Percenters  Bounces  Goal Assists  % Played  \
# playerId    year+1
# 1993707514  2013              6.11     0.00          0.00      0.89
#             2014              5.00     0.15          0.08      0.89
#             2015              6.40     0.00          0.07      0.85
#             2016              7.14     0.00          0.14      0.83
# 1996722607  2013              1.22     2.13          0.78      0.87
# ...                            ...      ...           ...       ...
# 20151001643 2018              1.00     0.29          0.64      0.82
#             2019              1.00     0.43          0.81      0.81
#             2020              0.76     0.41          0.76      0.78
#             2021              1.10     0.20          0.40      0.87
#             2022              1.00     0.00          0.65      0.83
#
#                     Player Team Score  Opponent Team Score  Margin  \
# playerId    year+1
# 1993707514  2013                96.83                95.94    0.89
#             2014                96.85                88.62    8.23
#             2015                85.13                74.67   10.47
#             2016                81.86                78.29    3.57
# 1996722607  2013               105.43                98.22    7.22
# ...                               ...                  ...     ...
# 20151001643 2018                92.57                91.79    0.79
#             2019                93.43                72.90   20.52
#             2020                80.82                75.94    4.88
#             2021                59.30                55.30    4.00
#             2022                69.65                80.90  -11.25
#
#                     Total Points Scored  Game Result  gameNumber
# playerId    year+1
# 1993707514  2013                   0.44         0.56      356.50
#             2014                   0.00         0.62      372.00
#             2015                   0.40         0.60      386.00
#             2016                   1.00         0.43      397.00
# 1996722607  2013                   9.52         0.61      335.00
# ...                                 ...          ...         ...
# 20151001643 2018                   6.57         0.46       43.50
#             2019                  14.76         0.76       61.00
#             2020                  13.29         0.59       80.00
#             2021                   9.60         0.55       93.50
#             2022                   8.05         0.30      108.50
#
# [6634 rows x 29 columns]

# %% [markdown]
# ## Creating a target feature from AFL Fantasy and Supercoach point values

# %%
afl_fantasy_points = {'Kicks': 3,
                      'Marks': 3,
                      'Handballs': 2,
                      'Goals': 6,
                      'Behinds': 1,
                      'Hit Outs': 1,
                      'Tackles': 4,
                      'Frees': 1,
                      'Frees Against': -3}

# %%
supercoach_points = {'Kicks': 4,
                     'Handballs': 1.5,
                     'Marks': 6,
                     'Tackles': 4, 
                     'Frees': 4, 
                     'Frees Against': -4, 
                     'Hit Outs': 5, 
                     'Goals': 8, 
                     'Behinds': 1}

# %%
from functools import reduce

def get_fantasy_points(dataset, points_dict, column_name):
    fantasy_list = []
    for col_name, pts in points_dict.items():
        col_vals = dataset[col_name] * pts
        fantasy_list.append(col_vals)
    dataset.insert(0, column_name, reduce((lambda x, y: x + y), fantasy_list))
    return dataset

# %%
df_final = get_fantasy_points(df_final, afl_fantasy_points, 'AFL Fantasy Points')
df_final = get_fantasy_points(df_final, supercoach_points, 'Supercoach Points')

# %% [markdown]
# ### Dropping redundant or irrelevant columns

# %%
df_final.drop(['homeTeamScore', 'awayTeamScore', 'playerId', 'gameId', 'year+1'], axis=1, inplace=True)

# %% [markdown]
# ### Dropping columns of data that would be unavailable the day of the game

# %%
drop_column_list = ['Disposals', 'Kicks', 'Marks', 'Handballs', 'Goals', 'Behinds', 'Hit Outs', 
                   'Tackles', 'Rebounds', 'Inside 50s', 'Clearances', 'Clangers', 'Frees', 
                   'Frees Against', 'Brownlow Votes', 'Contested Possessions', 'Bounces',
                   'Uncontested Possessions', 'Contested Marks', 'Marks Inside 50', 'One Percenters',
                   '% Played', 'Subs', 'Total Points Scored',  'Goal Assists', 'Player Team Score',
                   'Opponent Team Score', 'Margin', 'Game Result', 'attendance', 'rainfall']

df_final.drop(drop_column_list, axis=1, inplace=True)

# %% [markdown]
# ### Normalizing columns by round and by game

# %%
exclude_from_normalization = ['year', 'round', 'Is Home Team', 'Month', 'Day of Year', 'Weekday',
                              'Midfield', 'Forward', 'Defender', 'Ruck', 'AFL Fantasy Points', 
                              'Supercoach Points']

normalization_list = [col for col in df_final.select_dtypes(exclude=object).columns 
                      if col not in exclude_from_normalization]

# %%
def normalization_func(dataframe, column_list):
    for col in column_list:
        df_round = dataframe.groupby(['year', 'round'])[col]
        dataframe[f'{col}_round_norm'] = df_round.transform(lambda x: (x - min(x))/(max(x)-min(x)))

        df_game = dataframe.groupby(['year', 'round', 'homeTeam'])[col]
        dataframe[f'{col}_game_norm'] = df_game.transform(lambda x: (x - min(x))/(max(x)-min(x)))
    return dataframe

# %%
df_final = normalization_func(df_final, normalization_list)
df_final
# Out:
#        Supercoach Points  AFL Fantasy Points  year  round  height   Age  \
# 0                  62.00                  50  2021      1     181 19.10
# 1                  24.50                  21  2021      1     181 28.49
# 2                  49.50                  35  2021      1     198 21.22
# 3                  90.00                  65  2021      1     188 24.05
# 4                 147.00                  83  2021      1     200 24.33
# ...                  ...                 ...   ...    ...     ...   ...
# 89465              15.50                  12  2012     23     189 23.18
# 89466             110.50                  85  2012     23     181 19.31
# 89467             131.50                  88  2012     23     194 19.56
# 89468              96.50                  77  2012     23     186 19.86
# 89469             132.50                  90  2012     23     187 23.00
#
#        weight              team  gameNumber          venue  ...  \
# 0          81          Adelaide           1  Adelaide Oval  ...
# 1          81          Adelaide         168  Adelaide Oval  ...
# 2          83          Adelaide           3  Adelaide Oval  ...
# 3          88          Adelaide          31  Adelaide Oval  ...
# 4          90          Adelaide           9  Adelaide Oval  ...
# ...       ...               ...         ...            ...  ...
# 89465      79  Western Bulldogs           8          Gabba  ...
# 89466      85  Western Bulldogs          16          Gabba  ...
# 89467      94  Western Bulldogs           4          Gabba  ...
# 89468      85  Western Bulldogs          25          Gabba  ...
# 89469      86  Western Bulldogs          42          Gabba  ...
#
#       Opponent Team Score_prevous_year_mean_round_norm  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 89465                                              NaN
# 89466                                              NaN
# 89467                                              NaN
# 89468                                              NaN
# 89469                                              NaN
#
#        Opponent Team Score_prevous_year_mean_game_norm  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 89465                                              NaN
# 89466                                              NaN
# 89467                                              NaN
# 89468                                              NaN
# 89469                                              NaN
#
#        Margin_prevous_year_mean_round_norm  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 89465                                  NaN
# 89466                                  NaN
# 89467                                  NaN
# 89468                                  NaN
# 89469                                  NaN
#
#        Margin_prevous_year_mean_game_norm  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 89465                                 NaN
# 89466                                 NaN
# 89467                                 NaN
# 89468                                 NaN
# 89469                                 NaN
#
#       Total Points Scored_prevous_year_mean_round_norm  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 89465                                              NaN
# 89466                                              NaN
# 89467                                              NaN
# 89468                                              NaN
# 89469                                              NaN
#
#        Total Points Scored_prevous_year_mean_game_norm  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 89465                                              NaN
# 89466                                              NaN
# 89467                                              NaN
# 89468                                              NaN
# 89469                                              NaN
#
#        Game Result_prevous_year_mean_round_norm  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 89465                                       NaN
# 89466                                       NaN
# 89467                                       NaN
# 89468                                       NaN
# 89469                                       NaN
#
#        Game Result_prevous_year_mean_game_norm  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 89465                                      NaN
# 89466                                      NaN
# 89467                                      NaN
# 89468                                      NaN
# 89469                                      NaN
#
#        gameNumber_prevous_year_mean_round_norm  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 89465                                      NaN
# 89466                                      NaN
# 89467                                      NaN
# 89468                                      NaN
# 89469                                      NaN
#
#        gameNumber_prevous_year_mean_game_norm
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 89465                                     NaN
# 89466                                     NaN
# 89467                                     NaN
# 89468                                     NaN
# 89469                                     NaN
#
# [89470 rows x 2058 columns]

# %%
# homeTeam is redundant but was needed for the normalization groupby
df_final.drop('homeTeam', axis=1, inplace=True)

# %% [markdown]
# ### Creating dummies columns and eliminating NaN and infinities

# %%
df_final_w_dummies = pd.get_dummies(df_final)

# %%
numerical_list = list(df_final_w_dummies.select_dtypes('number').columns)

# %%
total_rows = df_final_w_dummies.shape[0]

for col in numerical_list:
    total_nans = df_final_w_dummies[col].isna().sum()
    total_infs = df_final_w_dummies[col].isin([np.inf]).sum()
    total_neg_infs = df_final_w_dummies[col].isin([-np.inf]).sum()
    
    if total_rows in [total_nans, total_infs, total_neg_infs]:
        df_final_w_dummies.drop(col, axis=1, inplace=True)
        continue
    
    if df_final_w_dummies[col].isna().sum() != 0:
        df_final_w_dummies[f'{col}_nan'] = np.where(df_final_w_dummies[col].isna(), 1, 0)
    if df_final_w_dummies[col].isin([np.inf]).sum() != 0:
        df_final_w_dummies[f'{col}_inf'] = np.where(df_final_w_dummies[col].isin([np.inf]), 1, 0)
    if df_final_w_dummies[col].isin([-np.inf]).sum() != 0:
        df_final_w_dummies[f'{col}_neg_inf'] = np.where(df_final_w_dummies[col].isin([-np.inf]), 1, 0)
        
df_final_w_dummies.fillna(0, inplace=True)
df_final_w_dummies.replace(np.inf, 0, inplace=True)
df_final_w_dummies.replace(-np.inf, 0, inplace=True)

# %%
df_final_w_dummies.isin([np.inf, -np.inf, np.nan]).sum().where(lambda x: x > 0).dropna()
# Out:
# Series([], dtype: float64)

# %%
df_final_w_dummies.shape
# Out:
# (89470, 4407)

# %% [markdown]
# ### Spliting datasets into train and test for Fantasy and Supercoach

# %%
train_df = df_final_w_dummies.loc[~ df_final_w_dummies['year'].isin([2020, 2021])]
test_df = df_final_w_dummies.loc[df_final_w_dummies['year'].isin([2020, 2021])]

# %%
y_train_fantasy = train_df['AFL Fantasy Points']
y_test_fantasy = test_df['AFL Fantasy Points']

y_train_super = train_df['Supercoach Points']
y_test_super = test_df['Supercoach Points']


X_train_fantasy = train_df.drop(['AFL Fantasy Points', 'Supercoach Points'], axis=1)
X_test_fantasy = test_df.drop(['AFL Fantasy Points', 'Supercoach Points'], axis=1)

X_train_super = train_df.drop(['AFL Fantasy Points', 'Supercoach Points'], axis=1)
X_test_super = test_df.drop(['AFL Fantasy Points', 'Supercoach Points'], axis=1)

# %% [markdown]
# ## Creating Random Forest models

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn import metrics

# %%
rf = RandomForestRegressor(n_jobs=-1, random_state=0, verbose=2)

# %%
rf.fit(X_train_fantasy, y_train_fantasy)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100building tree 3 of 100building tree 4 of 100
#
# building tree 5 of 100
#
# building tree 6 of 100
# building tree 7 of 100building tree 8 of 100
#
#
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 28.2min
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 117.3min finished
# RandomForestRegressor(n_jobs=-1, random_state=0, verbose=2)

# %%
predict_X_train_fantasy = rf.predict(X_train_fantasy)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.6s finished

# %%
predict_X_test_fantasy = rf.predict(X_test_fantasy)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.5s finished

# %%
metrics.mean_absolute_error(y_train_fantasy, predict_X_train_fantasy)
# Out:
# 6.502905108486679

# %%
metrics.mean_absolute_error(y_test_fantasy, predict_X_test_fantasy)
# Out:
# 18.92823183183183

# %%
sorted(list(zip(X_train_fantasy.columns,rf.feature_importances_)), key=lambda x:x[1], reverse=True)
# Out:
# [('Disposals_cumulative_sum_round_norm', 0.15281097971957158),
#  ('Contested Possessions_prevous_year_mean', 0.04014172777683218),
#  ('Disposals_cumulative_max', 0.03056487540611994),
#  ('Disposals_prevous_year_mean', 0.020990961464108126),
#  ('Clearances_cumulative_sum_round_norm', 0.009048334632935993),
#  ('Disposals_cumulative_max_game_norm', 0.005016662127696937),
#  ('Kicks_prevous_year_mean', 0.0049192556819208895),
#  ('Clearances_cumulative_sum_game_norm', 0.004603703970999357),
#  ('gameNumber_game_norm', 0.003464545626620689),
#  ('One Percenters_prevous_year_mean', 0.0030001357193350413),
#  ('Disposals_shift_1', 0.0028168546945265107),
#  ('Clearances_prevous_year_sum', 0.0027738589517559325),
#  ('Hit Outs_cumulative_sum_round_norm', 0.0022489192373138),
#  ('Kicks_cumulative_sum_game_norm', 0.002052536876537804),
#  ('Kicks_shift_1', 0.0020452234381609547),
#  ('Age_game_norm', 0.001948598179921985),
#  ('weight_game_norm', 0.0019167502600377058),
#  ('Brownlow Votes_cumulative_sum_game_norm', 0.0018800243225528576),
#  ('Brownlow Votes_cumulative_sum_round_norm', 0.0018784167410579955),
#  ('height_game_norm', 0.001855516858397192),
#  ('Disposals_prevous_year_mean_round_norm', 0.001799907971576483),
#  ('Disposals_cumulative_max_round_norm', 0.001777213921839772),
#  ('Hit Outs_shift_1_game_norm', 0.0016709713111227522),
#  ('Brownlow Votes_prevous_year_mean', 0.0016629469795058644),
#  ('Kicks_cumulative_max_game_norm', 0.0016383184828643314),
#  ('Age_round_norm', 0.0016031415034586155),
#  ('weight_round_norm', 0.0015652680160754392),
#  ('Disposals_shift_1_game_norm', 0.0015570618139070969),
#  ('Disposals_cumulative_sum_game_norm', 0.0015455165514234263),
#  ('Hit Outs_cumulative_sum_game_norm', 0.0015050915411293727),
#  ('Hit Outs_shift_1', 0.001458529772498352),
#  ('gameNumber_round_norm', 0.0014246302677379413),
#  ('Age', 0.00140586320962103),
#  ('Kicks_cumulative_sum_round_norm', 0.0013816312235266986),
#  ('height_round_norm', 0.001381617856096185),
#  ('Inside 50s_cumulative_sum_round_norm', 0.0013676902190233589),
#  ('Kicks_prevous_year_mean_game_norm', 0.0013557794942969372),
#  ('Inside 50s_cumulative_sum_game_norm', 0.001343363664167167),
#  ('Disposals_shift_1_round_norm', 0.0013225628024030453),
#  ('Kicks_cumulative_min', 0.0012858513631418325),
#  ('Disposals_cumulative_min', 0.0011672779384132865),
#  ('Tackles_cumulative_sum_round_norm', 0.0011349478191988664),
#  ('Uncontested Possessions_cumulative_sum_game_norm', 0.0011240807547646904),
#  ('Contested Possessions_cumulative_sum_game_norm', 0.0011239779703426057),
#  ('Uncontested Possessions_prevous_year_mean', 0.001119763654664363),
#  ('Opponent Team Score_prevous_year_mean_game_norm', 0.0011167119392982443),
#  ('Disposals_prevous_year_mean_game_norm', 0.0011089435383068978),
#  ('year', 0.0011007003936225144),
#  ('Marks_cumulative_sum_round_norm', 0.0010977725239543746),
#  ('One Percenters_cumulative_sum_round_norm', 0.001093653670072015),
#  ('Contested Possessions_cumulative_sum_round_norm', 0.0010869100563873262),
#  ('Kicks_shift_1_game_norm', 0.001072693265438788),
#  ('Kicks_cumulative_min_round_norm', 0.0010686586042168115),
#  ('Clearances_shift_1', 0.001066867417814365),
#  ('Disposals_cumulative_min_round_norm', 0.0010596020097618495),
#  ('Inside 50s_prevous_year_sum', 0.0010504945532085889),
#  ('Kicks_cumulative_max_round_norm', 0.0010414576634151923),
#  ('Kicks_shift_1_round_norm', 0.0010298304400396393),
#  ('Tackles_cumulative_sum_game_norm', 0.0010226746315854418),
#  ('Uncontested Possessions_prevous_year_mean_game_norm', 0.001021907363521178),
#  ('Marks_cumulative_sum_game_norm', 0.0010200078080269805),
#  ('Disposals_cumulative_min_game_norm', 0.0010062737238934257),
#  ('One Percenters_prevous_year_mean_game_norm', 0.0009924272826465244),
#  ('Opponent Team Score_prevous_year_mean_round_norm', 0.0009722220426905871),
#  ('Uncontested Possessions_cumulative_sum_round_norm', 0.000971392030748252),
#  ('Marks Inside 50_cumulative_sum_game_norm', 0.0009452322885230614),
#  ('One Percenters_prevous_year_mean_round_norm', 0.0009417400390657831),
#  ('Contested Possessions_cumulative_max_game_norm', 0.0009410486827194828),
#  ('Hit Outs_prevous_year_sum', 0.000940223665408333),
#  ('Uncontested Possessions_shift_1_game_norm', 0.000931334311025162),
#  ('Uncontested Possessions_cumulative_max_game_norm', 0.0009161684736196841),
#  ('Day of Year', 0.0009143142430281664),
#  ('Tackles_prevous_year_mean', 0.0009052886543057532),
#  ('Clearances_shift_1_game_norm', 0.0008998950861822765),
#  ('Kicks_prevous_year_mean_round_norm', 0.0008932424460861576),
#  ('Marks_prevous_year_mean', 0.0008793527568884854),
#  ('Frees_prevous_year_mean_game_norm', 0.0008782338082006408),
#  ('Opponent Team Score_cumulative_min_round_norm', 0.0008774582552127895),
#  ('Handballs_prevous_year_mean', 0.0008716862629905027),
#  ('Uncontested Possessions_shift_1_round_norm', 0.0008707602034698269),
#  ('Handballs_cumulative_sum_round_norm', 0.0008666963501127542),
#  ('Frees Against_prevous_year_mean_game_norm', 0.0008641849623386298),
#  ('Contested Possessions_cumulative_max_round_norm', 0.0008640420948467489),
#  ('Kicks_shift_2_round_norm', 0.0008636595689304493),
#  ('Disposals_shift_2_game_norm', 0.0008626943229912297),
#  ('Player Team Score_cumulative_min_round_norm', 0.0008626629541632224),
#  ('Clangers_prevous_year_mean_game_norm', 0.0008620954894585666),
#  ('Clangers_cumulative_sum_game_norm', 0.0008576974217620632),
#  ('Inside 50s_prevous_year_mean_game_norm', 0.0008555998333481716),
#  ('% Played_prevous_year_mean_game_norm', 0.0008550877457860762),
#  ('Opponent Team Score_cumulative_sum_round_norm', 0.0008503214784448954),
#  ('Hit Outs_cumulative_min_game_norm', 0.0008497426361022167),
#  ('Player Team Score_prevous_year_mean_game_norm', 0.0008422524695972103),
#  ('Disposals_shift_2_round_norm', 0.0008409906960741161),
#  ('Goal Assists_cumulative_sum_game_norm', 0.0008361087546172347),
#  ('Handballs_shift_1_game_norm', 0.0008283447042546386),
#  ('Tackles_cumulative_max_game_norm', 0.0008274044225828977),
#  ('Tackles_prevous_year_mean_game_norm', 0.0008227935233102604),
#  ('Marks_cumulative_max_game_norm', 0.0008203473499152902),
#  ('% Played_shift_1_round_norm', 0.000819906635109382),
#  ('Contested Possessions_prevous_year_mean_game_norm', 0.0008191225038331561),
#  ('Kicks_cumulative_min_game_norm', 0.000818310440793334),
#  ('% Played_cumulative_max_round_norm', 0.000817386021839554),
#  ('Clearances_prevous_year_mean', 0.0008143536945061956),
#  ('Handballs_prevous_year_mean_game_norm', 0.0008132438566502029),
#  ('Margin_prevous_year_mean_round_norm', 0.0008128295730126138),
#  ('Margin_prevous_year_sum_game_norm', 0.0008094281002097719),
#  ('% Played_cumulative_min_game_norm', 0.0008086197942928291),
#  ('Frees_cumulative_sum_game_norm', 0.000807917755225285),
#  ('Margin_prevous_year_mean_game_norm', 0.0008049639859445108),
#  ('Player Team Score_prevous_year_mean_round_norm', 0.000804463154412518),
#  ('Marks_prevous_year_mean_game_norm', 0.0008042255897370805),
#  ('Opponent Team Score_cumulative_max_round_norm', 0.0008030965946035421),
#  ('Hit Outs_shift_1_round_norm', 0.0007996819677754646),
#  ('Opponent Team Score_cumulative_min_game_norm', 0.0007985855245476057),
#  ('Uncontested Possessions_cumulative_min_game_norm', 0.000795076599589939),
#  ('Tackles_cumulative_max_round_norm', 0.0007942701767484299),
#  ('Uncontested Possessions_cumulative_min_round_norm', 0.0007901793443366038),
#  ('Margin_cumulative_min_round_norm', 0.0007848171556245724),
#  ('Player Team Score_cumulative_max_round_norm', 0.000784155182763167),
#  ('% Played_exponential_mean_5_game_norm', 0.0007814199120549928),
#  ('% Played_shift_2_game_norm', 0.0007786537358109852),
#  ('% Played_cumulative_min_round_norm', 0.0007764245554271736),
#  ('Margin_cumulative_sum', 0.0007744642960125076),
#  ('weight', 0.0007728159136663398),
#  ('Marks_prevous_year_mean_round_norm', 0.0007712962021289193),
#  ('% Played_cumulative_sum_round_norm', 0.0007711396039465312),
#  ('gameNumber_boxcar_sum_5_game_norm', 0.0007703133037217274),
#  ('Handballs_shift_1_round_norm', 0.0007694062647505829),
#  ('height', 0.0007688809490271303),
#  ('Handballs_cumulative_max_round_norm', 0.0007687923723633875),
#  ('Frees Against_prevous_year_mean_round_norm', 0.00076739551464464),
#  ('Opponent Team Score_shift_2', 0.0007659705140274343),
#  ('Inside 50s_prevous_year_sum_round_norm', 0.0007607553152539008),
#  ('% Played_shift_1_game_norm', 0.0007602147586205126),
#  ('Margin_cumulative_sum_game_norm', 0.0007591610225548214),
#  ('Contested Possessions_cumulative_min_game_norm', 0.0007584222280892679),
#  ('% Played_prevous_year_mean_round_norm', 0.0007570957638374566),
#  ('Player Team Score_shift_2_round_norm', 0.0007501226171565438),
#  ('Frees_cumulative_sum_round_norm', 0.0007488704552779625),
#  ('% Played_prevous_year_mean', 0.0007488103047512651),
#  ('Player Team Score_shift_2', 0.0007473515854555051),
#  ('Marks Inside 50_prevous_year_mean_game_norm', 0.0007430623878825547),
#  ('Tackles_shift_1_game_norm', 0.000742154542434115),
#  ('Handballs_cumulative_max_game_norm', 0.0007408566217973458),
#  ('Uncontested Possessions_shift_2_game_norm', 0.000738882146323019),
#  ('Clangers_prevous_year_mean_round_norm', 0.0007387639499479733),
#  ('Contested Possessions_shift_1_game_norm', 0.0007383610154376843),
#  ('Contested Possessions_shift_1_round_norm', 0.0007378475385885192),
#  ('% Played_cumulative_max_game_norm', 0.0007372573165112782),
#  ('Tackles_prevous_year_mean_round_norm', 0.000737239772549425),
#  ('Opponent Team Score_shift_2_round_norm', 0.0007370346783823395),
#  ('Kicks_shift_2_game_norm', 0.0007363184011248152),
#  ('Uncontested Possessions_cumulative_max_round_norm', 0.0007349630678900948),
#  ('Marks Inside 50_cumulative_sum_round_norm', 0.0007345274353476553),
#  ('gameNumber', 0.0007334438166479028),
#  ('Margin_cumulative_sum_round_norm', 0.0007315489691551658),
#  ('Clearances_cumulative_max_game_norm', 0.0007273572806566493),
#  ('Inside 50s_prevous_year_mean', 0.0007271503618323022),
#  ('Margin_cumulative_max_round_norm', 0.0007267486875242342),
#  ('Goal Assists_prevous_year_mean_round_norm', 0.0007243582285520704),
#  ('Contested Possessions_prevous_year_mean_round_norm', 0.0007221928135974044),
#  ('Marks_cumulative_max_round_norm', 0.0007205407977208554),
#  ('Handballs_cumulative_sum_game_norm', 0.0007201089281265836),
#  ('Kicks_cumulative_max', 0.0007186653252259432),
#  ('Clangers_cumulative_sum_round_norm', 0.0007185914348850646),
#  ('Start Time Minute_round_norm', 0.0007168618554165875),
#  ('% Played_boxcar_sum_5_game_norm', 0.0007159942121876182),
#  ('gameNumber_boxcar_mean_5_game_norm', 0.0007158842324683118),
#  ('Inside 50s_prevous_year_mean_round_norm', 0.0007156164978995313),
#  ('Disposals_shift_3_game_norm', 0.0007141942227078391),
#  ('Player Team Score_cumulative_sum_round_norm', 0.0007127397213446128),
#  ('Kicks_shift_3_round_norm', 0.0007075649330458377),
#  ('Handballs_prevous_year_mean_round_norm', 0.0007046841789806948),
#  ('Opponent Team Score_cumulative_sum_game_norm', 0.0007032487468118917),
#  ('% Played_boxcar_mean_3_round_norm', 0.0007000601619595936),
#  ('Game Result_prevous_year_mean_game_norm', 0.0006982311756492082),
#  ('% Played_boxcar_mean_5_game_norm', 0.0006967409713323299),
#  ('Uncontested Possessions_prevous_year_mean_round_norm',
#   0.0006965189004383013),
#  ('Disposals_shift_3', 0.0006959069663653858),
#  ('Player Team Score_prevous_year_mean', 0.0006950911882278997),
#  ('Clearances_shift_1_round_norm', 0.0006932603604101375),
#  ('Contested Possessions_shift_2_round_norm', 0.0006908766677953596),
#  ('% Played_boxcar_mean_5_round_norm', 0.0006902262117603455),
#  ('Goal Assists_cumulative_sum_round_norm', 0.0006870242729069351),
#  ('Kicks_shift_3_game_norm', 0.0006869553624314535),
#  ('Tackles_shift_2_round_norm', 0.0006868183958678263),
#  ('Margin_shift_2', 0.0006824974997995496),
#  ('% Played_boxcar_sum_5_round_norm', 0.0006794009198884879),
#  ('Rebounds_cumulative_sum_round_norm', 0.0006788886343797809),
#  ('Marks_shift_1_round_norm', 0.0006786996239637639),
#  ('Day of Year_shift_1_round_norm', 0.0006785094427631097),
#  ('Handballs_cumulative_min_round_norm', 0.0006760465970534817),
#  ('Handballs_cumulative_min_game_norm', 0.0006730647375815642),
#  ('Marks Inside 50_prevous_year_mean_round_norm', 0.0006670999657338322),
#  ('Tackles_shift_1_round_norm', 0.0006660247683265763),
#  ('Margin_shift_3', 0.0006649234125946925),
#  ('Goal Assists_prevous_year_mean_game_norm', 0.0006645802868941888),
#  ('Opponent Team Score_prevous_year_mean', 0.0006638428601371022),
#  ('Marks_shift_1_game_norm', 0.0006635901230071791),
#  ('Handballs_shift_2_round_norm', 0.0006620916938791645),
#  ('Margin_shift_4', 0.0006619084078451162),
#  ('Inside 50s_prevous_year_sum_game_norm', 0.000660497619818738),
#  ('Disposals_shift_2', 0.0006603127628112015),
#  ('Inside 50s_cumulative_max_game_norm', 0.0006597905198493093),
#  ('Frees Against_cumulative_sum_round_norm', 0.0006542820889331267),
#  ('% Played_exponential_sum_5_game_norm', 0.0006501904157028851),
#  ('Disposals_shift_3_round_norm', 0.0006489386092821444),
#  ('Frees Against_cumulative_sum_game_norm', 0.0006488691673577088),
#  ('Margin_cumulative_max', 0.000645267476238222),
#  ('Contested Possessions_shift_2_game_norm', 0.0006443429598969372),
#  ('% Played_shift_2_round_norm', 0.0006435955621876287),
#  ('Uncontested Possessions_shift_2_round_norm', 0.0006384098538563384),
#  ('Marks_prevous_year_sum', 0.0006377106173647612),
#  ('Kicks_shift_2', 0.0006344772608661577),
#  ('Marks_prevous_year_sum_game_norm', 0.0006331273296436836),
#  ('% Played_shift_3_game_norm', 0.0006329701290426862),
#  ('Margin_shift_2_round_norm', 0.0006317569121065423),
#  ('Clangers_prevous_year_mean', 0.0006294042038821167),
#  ('% Played_exponential_mean_5_round_norm', 0.0006278621273402668),
#  ('Clearances_prevous_year_mean_game_norm', 0.0006274340930653948),
#  ('Clangers_boxcar_mean_5_round_norm', 0.0006258798125646062),
#  ('Behinds_cumulative_sum_round_norm', 0.0006258221190922476),
#  ('Tackles_prevous_year_sum_game_norm', 0.0006248787425394954),
#  ('% Played_triang_mean_5_round_norm', 0.0006248157384492395),
#  ('Clearances_prevous_year_sum_game_norm', 0.0006246918700932864),
#  ('One Percenters_cumulative_max_round_norm', 0.0006225415095209623),
#  ('Tackles_shift_2_game_norm', 0.0006221160195924054),
#  ('Clangers_prevous_year_sum_game_norm', 0.0006215278690923148),
#  ('Marks_shift_2_game_norm', 0.0006208414320658123),
#  ('Opponent Team Score_cumulative_min', 0.0006205653790698115),
#  ('Frees_prevous_year_sum_game_norm', 0.0006195962681125341),
#  ('Handballs_boxcar_mean_5_round_norm', 0.0006183874581723321),
#  ('Total Points Scored_cumulative_sum_round_norm', 0.0006169001998351073),
#  ('Opponent Team Score_shift_1_round_norm', 0.0006160551226625413),
#  ('% Played_boxcar_mean_5', 0.0006153829453466025),
#  ('Tackles_shift_3_round_norm', 0.0006150891167158447),
#  ('Handballs_shift_2_game_norm', 0.0006146624422924101),
#  ('% Played_cumulative_sum_game_norm', 0.0006137700653102497),
#  ('One Percenters_prevous_year_sum_game_norm', 0.0006124150390202611),
#  ('% Played_boxcar_mean_3_game_norm', 0.0006116060602574419),
#  ('Marks_cumulative_min_round_norm', 0.0006100061274177771),
#  ('Clangers_exponential_sum_5_round_norm', 0.0006092225511515891),
#  ('Opponent Team Score_shift_3_round_norm', 0.0006088877579703718),
#  ('Handballs_exponential_mean_5_game_norm', 0.00060792255876745),
#  ('One Percenters_cumulative_sum_game_norm', 0.0006079109299073623),
#  ('Contested Possessions_shift_3_game_norm', 0.0006061552983198909),
#  ('Clangers_exponential_mean_5_round_norm', 0.0006059894518025259),
#  ('Margin_shift_5', 0.000605551800684114),
#  ('% Played_exponential_mean_3_game_norm', 0.0006019568253631712),
#  ('Opponent Team Score_cumulative_max', 0.0006012334975414495),
#  ('Tackles_boxcar_mean_5_game_norm', 0.0006010223804051558),
#  ('% Played_cumulative_min', 0.0006007530046684069),
#  ('Marks_shift_2_round_norm', 0.0005999990182453628),
#  ('Contested Possessions_cumulative_min_round_norm', 0.0005982093002428284),
#  ('Opponent Team Score_shift_3', 0.0005978941303413327),
#  ('% Played_boxcar_sum_3_round_norm', 0.0005971200205824398),
#  ('Marks_exponential_mean_5_game_norm', 0.0005970510461584958),
#  ('One Percenters_boxcar_mean_5_round_norm', 0.0005960018218077914),
#  ('% Played_exponential_mean_3_round_norm', 0.0005952212207895921),
#  ('Behinds_prevous_year_mean_game_norm', 0.0005950672127533124),
#  ('One Percenters_cumulative_max_game_norm', 0.0005949511875522145),
#  ('Clangers_exponential_mean_5_game_norm', 0.0005933262447260674),
#  ('Contested Possessions_shift_3_round_norm', 0.0005922351369052948),
#  ('gameNumber_cumulative_sum_round_norm', 0.0005919454206666725),
#  ('One Percenters_shift_1_round_norm', 0.0005892589315050047),
#  ('Opponent Team Score_shift_5', 0.0005887623794077274),
#  ('gameNumber_cumulative_sum', 0.0005870876425025509),
#  ('Tackles_boxcar_sum_5_round_norm', 0.0005862834411096323),
#  ('% Played_boxcar_sum_3_game_norm', 0.0005853259470934913),
#  ('% Played_shift_4_game_norm', 0.0005845078740195495),
#  ('Frees Against_prevous_year_mean', 0.0005844218016783911),
#  ('Kicks_prevous_year_sum_game_norm', 0.0005832320676988417),
#  ('Tackles_boxcar_sum_5_game_norm', 0.000581660765926226),
#  ('Marks_boxcar_mean_5_game_norm', 0.0005795535722761949),
#  ('% Played_exponential_mean_5', 0.0005787015478072218),
#  ('Marks_exponential_sum_5_game_norm', 0.0005782633584760242),
#  ('Rebounds_prevous_year_mean_game_norm', 0.0005773933953575977),
#  ('Tackles_boxcar_mean_5_round_norm', 0.0005772680967405333),
#  ('gameNumber_boxcar_mean_5_round_norm', 0.0005771752045532771),
#  ('Margin_cumulative_min', 0.000576113796423706),
#  ('Margin_cumulative_min_game_norm', 0.0005756951226559131),
#  ('Player Team Score_cumulative_min', 0.000573587143915002),
#  ('Uncontested Possessions_boxcar_sum_5_game_norm', 0.000573278110941636),
#  ('Kicks_boxcar_sum_5_game_norm', 0.0005732273078895902),
#  ('% Played_triang_mean_5_game_norm', 0.000573094446408277),
#  ('Uncontested Possessions_boxcar_mean_5_game_norm', 0.0005718675643516714),
#  ('Opponent Team Score_shift_5_round_norm', 0.0005717106675523531),
#  ('Opponent Team Score_shift_2_game_norm', 0.0005708425569122738),
#  ('Marks_boxcar_sum_5_game_norm', 0.0005696163900275391),
#  ('Tackles_exponential_sum_5_game_norm', 0.0005690542258519324),
#  ('Inside 50s_boxcar_mean_5_game_norm', 0.0005685626898286598),
#  ('Player Team Score_cumulative_min_game_norm', 0.0005681417806365725),
#  ('Kicks_boxcar_mean_5_game_norm', 0.0005679125155046645),
#  ('Uncontested Possessions_shift_3_game_norm', 0.0005678899085274653),
#  ('gameNumber_exponential_sum_5_game_norm', 0.0005676516891114353),
#  ('Player Team Score_shift_3', 0.000567431888451052),
#  ('Contested Marks_cumulative_sum_round_norm', 0.0005672749877795936),
#  ('Handballs_boxcar_sum_5_game_norm', 0.0005657676339132746),
#  ('Handballs_boxcar_mean_5_game_norm', 0.0005655641626949815),
#  ('Kicks_shift_4_round_norm', 0.0005650156900058391),
#  ('Frees_prevous_year_mean_round_norm', 0.0005648591885309851),
#  ('Opponent Team Score_shift_4', 0.0005635366595896713),
#  ('Clangers_boxcar_mean_5_game_norm', 0.0005634288619773317),
#  ('Contested Marks_cumulative_sum_game_norm', 0.0005631492129739104),
#  ('Contested Possessions_boxcar_mean_5_game_norm', 0.0005628993797116768),
#  ('Handballs_shift_3_round_norm', 0.0005627198650650571),
#  ('Player Team Score_cumulative_max', 0.0005624576316006262),
#  ('Contested Possessions_prevous_year_sum_game_norm', 0.000559612763242996),
#  ('Player Team Score_shift_3_round_norm', 0.0005593114285601454),
#  ('Clangers_cumulative_max_game_norm', 0.0005590955371179401),
#  ('Uncontested Possessions_shift_3_round_norm', 0.0005585406000039918),
#  ('Disposals_shift_4_round_norm', 0.0005578501632533463),
#  ('Clearances_shift_2_game_norm', 0.0005578422840849725),
#  ('Frees_prevous_year_mean', 0.0005560835125276783),
#  ('Tackles_exponential_mean_5_game_norm', 0.0005560490010764837),
#  ('Rebounds_cumulative_sum_game_norm', 0.000555987057471067),
#  ('One Percenters_boxcar_mean_5_game_norm', 0.0005559405168769065),
#  ('Total Points Scored_cumulative_max_round_norm', 0.000555100407947482),
#  ('gameNumber_boxcar_sum_5_round_norm', 0.0005547471481561718),
#  ('Inside 50s_boxcar_mean_5_round_norm', 0.0005543602422447189),
#  ('% Played_shift_3_round_norm', 0.0005514195951746893),
#  ('Frees Against_prevous_year_sum_game_norm', 0.0005509290523065321),
#  ('Contested Possessions_exponential_mean_5_round_norm',
#   0.0005507467492300534),
#  ('Marks Inside 50_prevous_year_sum_game_norm', 0.0005503858795668073),
#  ('Opponent Team Score_cumulative_max_game_norm', 0.0005501029233952255),
#  ('Kicks_boxcar_mean_5_round_norm', 0.0005497964343409975),
#  ('Clearances_cumulative_max_round_norm', 0.0005497836222310209),
#  ('Opponent Team Score_shift_4_round_norm', 0.0005489149894942614),
#  ('Goal Assists_prevous_year_sum_game_norm', 0.0005479100132337031),
#  ('gameNumber_exponential_mean_5_game_norm', 0.0005473192064694519),
#  ('Contested Possessions_exponential_mean_5_game_norm', 0.0005471748696955374),
#  ('% Played_triang_sum_5_game_norm', 0.0005461802912190623),
#  ('Day of Year_shift_2_round_norm', 0.000545703244074292),
#  ('Marks_exponential_mean_5_round_norm', 0.0005444995878584177),
#  ('Handballs_prevous_year_sum_game_norm', 0.0005433922050483183),
#  ('Marks_shift_3_game_norm', 0.0005424850453604373),
#  ('Total Points Scored_cumulative_max_game_norm', 0.0005407554605544051),
#  ('Inside 50s_shift_1_game_norm', 0.0005398605944069734),
#  ('gameNumber_boxcar_mean_3_game_norm', 0.0005396734318072648),
#  ('Inside 50s_shift_2_round_norm', 0.0005396138384784359),
#  ('Clearances_prevous_year_sum_round_norm', 0.0005388574251634863),
#  ('Opponent Team Score_shift_3_game_norm', 0.0005376350280622607),
#  ('Handballs_shift_3_game_norm', 0.0005375596425892088),
#  ('Opponent Team Score_prevous_year_sum_game_norm', 0.0005372516600431663),
#  ('gameNumber_cumulative_sum_game_norm', 0.0005364727008301223),
#  ('One Percenters_boxcar_sum_5_round_norm', 0.0005335570779216588),
#  ('Clangers_exponential_mean_5', 0.0005325047568660242),
#  ('% Played_exponential_mean_3', 0.0005320166605244095),
#  ('Marks_triang_mean_5_game_norm', 0.0005318896143885994),
#  ('Contested Possessions_boxcar_sum_5_game_norm', 0.0005318581820511947),
#  ('Marks_shift_3_round_norm', 0.0005314923254776294),
#  ('Marks_boxcar_mean_3_game_norm', 0.0005309907086999896),
#  ('% Played_shift_1', 0.0005301353551020226),
#  ('Goal Assists_prevous_year_mean', 0.0005291914233519759),
#  ('Clangers_shift_1_round_norm', 0.0005283458256420355),
#  ('Marks Inside 50_prevous_year_mean', 0.0005283111357475322),
#  ('Marks_boxcar_sum_3_game_norm', 0.0005272375919383192),
#  ('Inside 50s_boxcar_sum_5_round_norm', 0.0005270074367190177),
#  ('Uncontested Possessions_boxcar_sum_5_round_norm', 0.0005261220313944084),
#  ('Total Points Scored_cumulative_sum_game_norm', 0.0005260683525193033),
#  ('Margin_shift_3_round_norm', 0.0005260310642337527),
#  ('Behinds_prevous_year_mean_round_norm', 0.000525679162557116),
#  ('Contested Possessions_boxcar_mean_5_round_norm', 0.0005252405220223012),
#  ('Clangers_prevous_year_sum_round_norm', 0.0005248978223509612),
#  ('Inside 50s_exponential_mean_5_game_norm', 0.0005236687901097565),
#  ('Contested Marks_prevous_year_mean_game_norm', 0.0005235673260524283),
#  ('Kicks_boxcar_sum_5_round_norm', 0.0005233990296299961),
#  ('Player Team Score_cumulative_max_game_norm', 0.0005229388725803086),
#  ('Inside 50s_boxcar_sum_5_game_norm', 0.0005227072854917754),
#  ('Handballs_exponential_mean_5_round_norm', 0.0005220089734625333),
#  ('Margin_prevous_year_sum_round_norm', 0.0005219652943074336),
#  ('Contested Marks_prevous_year_sum_game_norm', 0.0005215969841431697),
#  ('Clearances_shift_2_round_norm', 0.0005214803731998402),
#  ('Uncontested Possessions_prevous_year_sum_game_norm', 0.0005214762697262675),
#  ('Tackles_triang_mean_5_round_norm', 0.0005211147911681461),
#  ('Inside 50s_shift_1_round_norm', 0.0005210023378150391),
#  ('Handballs_exponential_sum_5_game_norm', 0.0005203232684746319),
#  ('Rebounds_boxcar_mean_5_game_norm', 0.0005197814352861204),
#  ('Marks_boxcar_sum_5_round_norm', 0.0005192156470504735),
#  ('Tackles_cumulative_min_round_norm', 0.000518131371288902),
#  ('% Played_triang_sum_5_round_norm', 0.000517714434883755),
#  ('Inside 50s_shift_2_game_norm', 0.0005174790680647448),
#  ('Rebounds_boxcar_sum_5_round_norm', 0.0005174772025882442),
#  ('Handballs_boxcar_mean_3_game_norm', 0.0005174117696551202),
#  ('Kicks_exponential_mean_5_game_norm', 0.0005169141577928168),
#  ('Rebounds_exponential_mean_5_game_norm', 0.0005168614506177798),
#  ('Kicks_exponential_sum_5_game_norm', 0.0005160296994456959),
#  ('Tackles_exponential_mean_5_round_norm', 0.0005159142249094399),
#  ('Disposals_prevous_year_sum_game_norm', 0.0005153946070451569),
#  ('Uncontested Possessions_exponential_mean_5_game_norm',
#   0.0005146453943823552),
#  ('% Played_exponential_sum_5_round_norm', 0.0005140686286796476),
#  ('Marks_boxcar_mean_5_round_norm', 0.000512874671101147),
#  ('gameNumber_triang_mean_5_game_norm', 0.0005127205023722201),
#  ('Tackles_shift_3_game_norm', 0.000512325653012124),
#  ('Disposals_boxcar_mean_5_game_norm', 0.0005119456604273521),
#  ('Bounces_cumulative_sum_round_norm', 0.0005111424548337912),
#  ('Contested Possessions_boxcar_sum_5_round_norm', 0.0005106304166109237),
#  ('Disposals_shift_4_game_norm', 0.0005103350889908561),
#  ('Inside 50s_exponential_mean_5_round_norm', 0.0005102865586814426),
#  ('Marks_cumulative_min_game_norm', 0.0005100183682151645),
#  ('One Percenters_exponential_sum_5_game_norm', 0.0005097645213127375),
#  ('Player Team Score_shift_2_game_norm', 0.0005097148142333953),
#  ('Frees Against_exponential_sum_5_game_norm', 0.000509420023715233),
#  ('Clangers_shift_1_game_norm', 0.0005091002831599022),
#  ('Frees Against_exponential_mean_5_game_norm', 0.0005087409820231745),
#  ('Margin_prevous_year_mean', 0.0005073879855738219),
#  ('Brownlow Votes_prevous_year_mean_game_norm', 0.0005068085070606605),
#  ('One Percenters_exponential_mean_5_round_norm', 0.000506556486400019),
#  ('Opponent Team Score_exponential_sum_5_game_norm', 0.0005055059555245838),
#  ('Player Team Score_exponential_sum_5_round_norm', 0.0005050026529166124),
#  ('Uncontested Possessions_boxcar_mean_5_round_norm', 0.0005041937412005405),
#  ('Kicks_boxcar_mean_3_round_norm', 0.0005041335557620603),
#  ('Margin_shift_1_round_norm', 0.0005034568398446786),
#  ('Rebounds_exponential_sum_5_game_norm', 0.0005033959835835952),
#  ('gameNumber_triang_sum_5_game_norm', 0.0005033362982822937),
#  ('Clangers_exponential_mean_3_round_norm', 0.0005023453537011247),
#  ('Handballs_boxcar_sum_5_round_norm', 0.0005010902233401542),
#  ('Frees_boxcar_mean_5_round_norm', 0.0005003826632342338),
#  ('Behinds_cumulative_sum_game_norm', 0.0004995529344827496),
#  ('Inside 50s_cumulative_max_round_norm', 0.0004981640371041101),
#  ('Clangers_boxcar_sum_5_game_norm', 0.0004974099632204329),
#  ('Goals_cumulative_sum_round_norm', 0.0004974030893365028),
#  ('Rebounds_prevous_year_mean', 0.0004973676180160687),
#  ('% Played_shift_5_game_norm', 0.0004968855971303126),
#  ('One Percenters_boxcar_mean_3_round_norm', 0.0004968779276644192),
#  ('Rebounds_prevous_year_mean_round_norm', 0.000496630586783261),
#  ('Clearances_cumulative_max', 0.0004959544059352867),
#  ('Player Team Score_shift_4_round_norm', 0.0004959165606144354),
#  ('Disposals_boxcar_sum_5_game_norm', 0.0004955897872469988),
#  ('Tackles_triang_sum_5_game_norm', 0.0004947320574685446),
#  ('Tackles_exponential_mean_3_game_norm', 0.0004944315981036589),
#  ('Tackles_boxcar_mean_3_round_norm', 0.0004942976936312695),
#  ('Rebounds_boxcar_sum_5_game_norm', 0.0004935047462128471),
#  ('One Percenters_exponential_mean_5_game_norm', 0.0004934247243664452),
#  ('Clangers_boxcar_sum_5_round_norm', 0.0004933146239479257),
#  ('Player Team Score_cumulative_sum_game_norm', 0.0004927090498759071),
#  ('Margin_shift_2_game_norm', 0.0004923304408198623),
#  ('Clangers_exponential_sum_5_game_norm', 0.0004910942570568277),
#  ('gameNumber_boxcar_mean_5', 0.0004902224518141316),
#  ('One Percenters_shift_1_game_norm', 0.0004901695711682411),
#  ('Handballs_exponential_mean_5', 0.000490144426838437),
#  ('Player Team Score_shift_4', 0.0004900047165538814),
#  ('% Played_exponential_sum_3_game_norm', 0.0004898750679025335),
#  ('gameNumber_boxcar_sum_3_game_norm', 0.0004897844331644989),
#  ('Player Team Score_shift_1_round_norm', 0.0004889205768678),
#  ('Clearances_boxcar_mean_5_game_norm', 0.000488833634927681),
#  ('Margin_shift_3_game_norm', 0.000488328321683031),
#  ('Opponent Team Score_cumulative_sum', 0.0004873533638751612),
#  ('One Percenters_exponential_sum_5_round_norm', 0.0004869708977970743),
#  ('% Played_triang_mean_5', 0.0004868276829718061),
#  ('Tackles_triang_mean_5_game_norm', 0.0004860653072139844),
#  ('Tackles_prevous_year_sum', 0.000486015180971426),
#  ('Tackles_exponential_sum_3_game_norm', 0.0004858875569130668),
#  ('Handballs_triang_mean_5_game_norm', 0.00048578660026826824),
#  ('Rebounds_triang_mean_5_game_norm', 0.00048567693974739756),
#  ('% Played_shift_4_round_norm', 0.0004855583401561656),
#  ('gameNumber_exponential_mean_5', 0.0004844597420191339),
#  ('Marks_cumulative_sum', 0.00048407596622426806),
#  ('% Played_shift_5_round_norm', 0.0004839275630201121),
#  ('% Played_triang_sum_3_game_norm', 0.00048357837078961854),
#  ('Tackles_boxcar_mean_3_game_norm', 0.00048356356526743876),
#  ('Clangers_triang_mean_5_game_norm', 0.0004834558653036496),
#  ('Kicks_boxcar_sum_3_game_norm', 0.00048304871363545154),
#  ('Contested Possessions_exponential_sum_5_round_norm', 0.0004827153892155111),
#  ('Kicks_boxcar_mean_3_game_norm', 0.0004822554664292243),
#  ('Frees_exponential_sum_5_game_norm', 0.0004822354432382634),
#  ('Start Time Hour_round_norm', 0.00048200144909849816),
#  ('Clangers_boxcar_mean_3_game_norm', 0.0004812003590674758),
#  ('Contested Possessions_exponential_sum_5_game_norm', 0.00048065384801603494),
#  ('Frees_prevous_year_sum_round_norm', 0.00047933247417582454),
#  ('One Percenters_shift_2_game_norm', 0.00047910886487822525),
#  ('Kicks_shift_4_game_norm', 0.00047870889224489044),
#  ('% Played_triang_mean_3_game_norm', 0.0004777914364621472),
#  ('Marks_shift_4_game_norm', 0.000477357398090208),
#  ('Rebounds_prevous_year_sum_game_norm', 0.00047612462564989606),
#  ('Uncontested Possessions_shift_4_game_norm', 0.00047585331432561793),
#  ('Uncontested Possessions_boxcar_sum_3_game_norm', 0.00047572152621621987),
#  ('Marks_exponential_sum_5_round_norm', 0.0004752872409166627),
#  ('Marks_shift_4_round_norm', 0.00047516737500569726),
#  ('Marks_triang_sum_5_game_norm', 0.0004750889578900648),
#  ('Opponent Team Score_shift_1_game_norm', 0.00047508088336781765),
#  ('Clangers_cumulative_max_round_norm', 0.0004746197675646081),
#  ('Frees Against_boxcar_mean_5_round_norm', 0.0004745217571652061),
#  ('Rebounds_boxcar_mean_5_round_norm', 0.00047412095274698414),
#  ('Tackles_exponential_sum_5', 0.0004739040647033486),
#  ('Frees Against_prevous_year_sum_round_norm', 0.00047329962193724194),
#  ('Behinds_prevous_year_mean', 0.0004731703006004147),
#  ('Inside 50s_exponential_sum_5_game_norm', 0.0004730822367236703),
#  ('Clangers_boxcar_mean_3_round_norm', 0.000472632011165408),
#  ('Clangers_exponential_sum_3_round_norm', 0.0004718863506824876),
#  ('Hit Outs_cumulative_max_game_norm', 0.0004713673523631378),
#  ('Uncontested Possessions_exponential_sum_5_game_norm',
#   0.00047116219302706516),
#  ('% Played_prevous_year_sum_game_norm', 0.00047103600886452596),
#  ('Clearances_prevous_year_mean_round_norm', 0.00047103053121391394),
#  ('Contested Possessions_exponential_mean_3_game_norm', 0.0004699602184481273),
#  ('Tackles_boxcar_sum_3_game_norm', 0.0004699099515464974),
#  ('Marks_exponential_mean_3_game_norm', 0.0004696606551311633),
#  ('Opponent Team Score_prevous_year_sum_round_norm', 0.00046907067580839094),
#  ('Frees_boxcar_mean_5_game_norm', 0.00046828916415794287),
#  ('Handballs_prevous_year_sum_round_norm', 0.0004681687395271488),
#  ('Opponent Team Score_shift_1', 0.00046790236733343046),
#  ('Handballs_exponential_mean_3_game_norm', 0.0004675514726571493),
#  ('Marks_exponential_sum_3_game_norm', 0.0004668367721518446),
#  ('Tackles_exponential_sum_5_round_norm', 0.00046657077063223915),
#  ('Bounces_prevous_year_mean_game_norm', 0.0004664418942863567),
#  ('Marks_prevous_year_sum_round_norm', 0.0004662037445350166),
#  ('Contested Possessions_boxcar_mean_3_game_norm', 0.0004656365138457848),
#  ('Contested Possessions_triang_mean_5_game_norm', 0.000465577735329458),
#  ('Clangers_triang_mean_5_round_norm', 0.0004653136722504564),
#  ('Clangers_exponential_sum_5', 0.0004647779913110368),
#  ('Uncontested Possessions_shift_4_round_norm', 0.00046453245196100614),
#  ('Handballs_shift_4_round_norm', 0.0004644771987971995),
#  ('Frees Against_boxcar_mean_5_game_norm', 0.0004643894716137861),
#  ('Clearances_boxcar_mean_5_round_norm', 0.0004638260546531509),
#  ('Clangers_shift_2_game_norm', 0.00046309885907413215),
#  ('Disposals_boxcar_sum_3_game_norm', 0.00046214798639775096),
#  ('One Percenters_exponential_sum_5', 0.0004619573122166615),
#  ('Inside 50s_triang_mean_5_round_norm', 0.0004619359025814601),
#  ('Tackles_triang_sum_5_round_norm', 0.0004619257066632513),
#  ('Margin_cumulative_max_game_norm', 0.00046136692173064304),
#  ('Frees Against_exponential_sum_5_round_norm', 0.00046133360712565923),
#  ('Contested Possessions_boxcar_sum_3_game_norm', 0.0004608359164706218),
#  ('Clangers_triang_sum_5_round_norm', 0.000460716035722643),
#  ('Handballs_boxcar_sum_3_game_norm', 0.000460660979624805),
#  ('Clangers_exponential_mean_3_game_norm', 0.00046063455557083404),
#  ('Frees_exponential_mean_5_game_norm', 0.00046043119062420655),
#  ('Kicks_exponential_mean_5_round_norm', 0.0004602802139729114),
#  ('Handballs_prevous_year_sum', 0.00046018499689035936),
#  ('Handballs_exponential_sum_5_round_norm', 0.0004601327913009447),
#  ('Tackles_prevous_year_sum_round_norm', 0.0004598863779867994),
#  ('Opponent Team Score_exponential_sum_5_round_norm', 0.0004597766139424338),
#  ('Player Team Score_shift_5', 0.0004597700801500329),
#  ('gameNumber_exponential_sum_5', 0.0004593730139117937),
#  ('gameNumber_boxcar_sum_5', 0.0004586298498521319),
#  ('Player Team Score_exponential_sum_5_game_norm', 0.0004585625966762252),
#  ('One Percenters_exponential_mean_3_game_norm', 0.0004581006303787684),
#  ('Contested Possessions_boxcar_mean_3_round_norm', 0.00045762074537430373),
#  ('Brownlow Votes_cumulative_sum', 0.00045754799896465616),
#  ('Marks_boxcar_mean_3_round_norm', 0.00045684180414226096),
#  ('% Played_boxcar_sum_5', 0.00045580960783840824),
#  ('Contested Possessions_exponential_mean_3_round_norm', 0.000455640824455645),
#  ('Frees Against_exponential_mean_5_round_norm', 0.00045538708617185467),
#  ('Contested Possessions_shift_4_round_norm', 0.000455279252548991),
#  ('Inside 50s_exponential_mean_3_game_norm', 0.0004551256636392932),
#  ('Inside 50s_triang_sum_5_game_norm', 0.00045494387325937353),
#  ('One Percenters_triang_sum_5_game_norm', 0.00045485760625971807),
#  ('Handballs_triang_mean_5_round_norm', 0.000454643715416926),
#  ('Kicks_shift_3', 0.0004545696224453667),
#  ('gameNumber_prevous_year_sum_game_norm', 0.00045456071696156354),
#  ('Handballs_exponential_mean_3_round_norm', 0.00045421336358590804),
#  ('Clangers_shift_2_round_norm', 0.0004538346930330689),
#  ('One Percenters_triang_mean_5_game_norm', 0.00045348655333057983),
#  ('Contested Possessions_triang_mean_5_round_norm', 0.00045341897829911563),
#  ('gameNumber_exponential_mean_3_game_norm', 0.0004530223780523248),
#  ('Contested Possessions_shift_4_game_norm', 0.0004525620945500235),
#  ('Bounces_prevous_year_mean_round_norm', 0.00045214149606891303),
#  ('Opponent Team Score_boxcar_sum_5_game_norm', 0.0004518789293575297),
#  ('Frees_triang_mean_5_game_norm', 0.00045183649349234356),
#  ('One Percenters_boxcar_sum_5_game_norm', 0.00045179811379393754),
#  ('Contested Possessions_boxcar_sum_3_round_norm', 0.00045178609695547585),
#  ('Clangers_triang_sum_5_game_norm', 0.0004510036447803866),
#  ('gameNumber_exponential_mean_5_round_norm', 0.00045091623749590753),
#  ('Uncontested Possessions_boxcar_mean_3_game_norm', 0.00045071680242796694),
#  ('Opponent Team Score_boxcar_sum_5_round_norm', 0.0004505619875595405),
#  ('gameNumber_boxcar_sum_3_round_norm', 0.00045049336816580063),
#  ('Handballs_exponential_sum_5', 0.00045016921418195276),
#  ('Player Team Score_shift_3_game_norm', 0.000450166834676001),
#  ('Tackles_shift_4_round_norm', 0.0004501365897959974),
#  ('Player Team Score_boxcar_sum_5_game_norm', 0.0004500193343318265),
#  ('Handballs_triang_sum_5_round_norm', 0.00044957775139385224),
#  ('Frees_exponential_mean_5_round_norm', 0.00044905810517328974),
#  ('Uncontested Possessions_shift_1', 0.00044900809703258616),
#  ('Handballs_shift_5_round_norm', 0.00044842473576172894),
#  ('One Percenters_shift_2_round_norm', 0.0004482228071622588),
#  ('Tackles_boxcar_sum_3_round_norm', 0.0004476967323616598),
#  ('Opponent Team Score_shift_4_game_norm', 0.0004474088668076636),
#  ('Uncontested Possessions_cumulative_max', 0.00044656350733703596),
#  ('Tackles_exponential_mean_3_round_norm', 0.00044618893132795636),
#  ('gameNumber_prevous_year_mean_game_norm', 0.0004446211496610134),
#  ('Handballs_boxcar_sum_3_round_norm', 0.0004445778226388785),
#  ('One Percenters_exponential_sum_3_game_norm', 0.0004438889596463363),
#  ('One Percenters_triang_sum_5_round_norm', 0.00044382418772526524),
#  ('One Percenters_boxcar_mean_3_game_norm', 0.0004437419319228583),
#  ('Disposals_boxcar_mean_3_game_norm', 0.0004432196758512197),
#  ('Rebounds_prevous_year_sum_round_norm', 0.0004430879180930375),
#  ('Marks_exponential_sum_5', 0.00044281779998151373),
#  ('Player Team Score_prevous_year_sum_game_norm', 0.0004426179164626022),
#  ('Handballs_cumulative_sum', 0.0004418330842040835),
#  ('gameNumber_exponential_sum_3_game_norm', 0.000441141229781771),
#  ('Contested Marks_prevous_year_mean_round_norm', 0.0004411145380093054),
#  ('Rebounds_exponential_sum_5_round_norm', 0.00044090899134719574),
#  ('% Played_shift_2', 0.00044053164549725946),
#  ('Inside 50s_triang_mean_5_game_norm', 0.000440387314081638),
#  ('Contested Possessions_exponential_sum_5', 0.0004401995736352586),
#  ('Handballs_shift_4_game_norm', 0.0004396836354212773),
#  ('Uncontested Possessions_triang_mean_5_game_norm', 0.00043954064289897606),
#  ('Margin_shift_4_round_norm', 0.0004392349886446055),
#  ('gameNumber_triang_sum_5_round_norm', 0.0004389399260680202),
#  ('Tackles_exponential_sum_3_round_norm', 0.0004386949159428751),
#  ('Inside 50s_exponential_sum_3_game_norm', 0.0004383778765766809),
#  ('Clearances_cumulative_min_round_norm', 0.00043820787438039716),
#  ('Margin_shift_5_round_norm', 0.0004381733517335691),
#  ('gameNumber_exponential_sum_5_round_norm', 0.00043816652624684296),
#  ('Disposals_boxcar_mean_5_round_norm', 0.00043786162998081556),
#  ('One Percenters_exponential_mean_5', 0.0004375637874402152),
#  ('gameNumber_triang_mean_3_game_norm', 0.000437194282783838),
#  ('Brownlow Votes_prevous_year_sum_game_norm', 0.0004368552558757474),
#  ('One Percenters_shift_3_round_norm', 0.00043685001882294057),
#  ('Frees Against_triang_mean_5_game_norm', 0.000436682045360898),
#  ('Player Team Score_shift_5_round_norm', 0.0004365964968131423),
#  ('Rebounds_exponential_mean_5_round_norm', 0.0004365690351834912),
#  ('% Played_triang_sum_3_round_norm', 0.0004362290045257708),
#  ('One Percenters_triang_mean_5_round_norm', 0.00043605790874414683),
#  ('Marks_exponential_mean_5', 0.0004353201121175365),
#  ('Contested Possessions_triang_sum_5_game_norm', 0.00043516087244227215),
#  ('Disposals_exponential_mean_5_game_norm', 0.00043514800097256735),
#  ('% Played_triang_mean_3_round_norm', 0.00043491556441887976),
#  ('Disposals_boxcar_sum_5_round_norm', 0.00043480738394597473),
#  ('Marks Inside 50_prevous_year_sum_round_norm', 0.00043442105294800746),
#  ('Opponent Team Score_shift_5_game_norm', 0.00043397321537735797),
#  ('Kicks_exponential_mean_5', 0.0004339314448070846),
#  ('Uncontested Possessions_shift_5_game_norm', 0.0004335745893000572),
#  ('Behinds_prevous_year_sum_game_norm', 0.0004325847492724566),
#  ('Handballs_triang_sum_5_game_norm', 0.0004322498583746522),
#  ('One Percenters_exponential_sum_3_round_norm', 0.0004322192204230593),
#  ('Bounces_prevous_year_sum_game_norm', 0.0004321405600505275),
#  ('Rebounds_shift_1_round_norm', 0.00043176764522659264),
#  ('Clearances_cumulative_sum', 0.00043133324412003565),
#  ('Uncontested Possessions_boxcar_mean_3_round_norm', 0.00042999896215829587),
#  ('Disposals_shift_5_round_norm', 0.0004288772856041196),
#  ('Brownlow Votes_prevous_year_sum', 0.00042878038978798875),
#  ('One Percenters_boxcar_sum_3_round_norm', 0.0004285753998041534),
#  ('gameNumber_triang_mean_5_round_norm', 0.00042828144872158173),
#  ('Marks_exponential_mean_3_round_norm', 0.00042814107554166867),
#  ('Opponent Team Score_prevous_year_sum', 0.00042719901857785585),
#  ('% Played_exponential_sum_3_round_norm', 0.0004269157152659649),
#  ('Clearances_boxcar_sum_5_game_norm', 0.00042690333288773774),
#  ('Clangers_exponential_sum_3_game_norm', 0.0004266921878386997),
#  ('One Percenters_cumulative_sum', 0.00042641152717223075),
#  ('Defender', 0.00042576994730269884),
#  ('Kicks_triang_mean_5_round_norm', 0.0004254461600742948),
#  ('Handballs_boxcar_mean_3_round_norm', 0.00042472506313117405),
#  ('% Played_exponential_sum_5', 0.0004242506345769422),
#  ('Uncontested Possessions_triang_sum_5_game_norm', 0.00042353142509713956),
#  ('Tackles_exponential_mean_5', 0.00042337286655122876),
#  ('Uncontested Possessions_exponential_mean_5_round_norm',
#   0.00042328846080561753),
#  ('Marks_boxcar_sum_3_round_norm', 0.0004226486368706192),
#  ('Clearances_boxcar_sum_5_round_norm', 0.0004226112394316082),
#  ('Tackles_shift_5_round_norm', 0.00042152627891388377),
#  ('Frees_exponential_sum_5_round_norm', 0.00042056938169347184),
#  ('Inside 50s_boxcar_mean_3_game_norm', 0.0004201636088156837),
#  ('Marks_triang_sum_3_game_norm', 0.00042012083413557247),
#  ('Kicks_prevous_year_sum_round_norm', 0.0004197823743310015),
#  ('Inside 50s_exponential_sum_5_round_norm', 0.00041888857879420513),
#  ('Kicks_triang_mean_5_game_norm', 0.00041887805011128835),
#  ('Uncontested Possessions_exponential_mean_5', 0.00041864738305824356),
#  ('Tackles_triang_mean_3_game_norm', 0.00041816300567077064),
#  ('Disposals_shift_5_game_norm', 0.0004180998924095866),
#  ('Start Time Minute', 0.00041779330860143425),
#  ('Player Team Score_shift_1_game_norm', 0.0004173145044582172),
#  ('Marks_triang_sum_5_round_norm', 0.00041722605477762756),
#  ('Contested Possessions_shift_5_round_norm', 0.0004162139041725568),
#  ('Total Points Scored_prevous_year_sum', 0.00041619362732523514),
#  ('Clangers_triang_mean_3_round_norm', 0.00041572325044708305),
#  ('Uncontested Possessions_exponential_sum_5_round_norm',
#   0.0004156861112346984),
#  ('Rebounds_cumulative_max_round_norm', 0.00041557848150897933),
#  ('Marks_triang_mean_3_game_norm', 0.0004153144948379605),
#  ('Uncontested Possessions_prevous_year_sum_round_norm',
#   0.0004140687788864489),
#  ('Clangers_prevous_year_sum', 0.0004139860297629097),
#  ('gameNumber_boxcar_mean_3_round_norm', 0.0004139281092395608),
#  ('Kicks_exponential_mean_3_game_norm', 0.000412975605468102),
#  ('Handballs_exponential_sum_3_round_norm', 0.00041251036344411974),
#  ('Uncontested Possessions_exponential_mean_3_game_norm',
#   0.0004123548236667032),
#  ('rainfall_shift_1_round_norm', 0.00041218089844416965),
#  ('Contested Possessions_exponential_mean_5', 0.00041190532051842816),
#  ('Game Result_cumulative_sum_round_norm', 0.00041183537205956305),
#  ('Uncontested Possessions_shift_2', 0.0004115620878581686),
#  ('Handballs_triang_mean_3_round_norm', 0.00041143495700201303),
#  ('gameNumber_triang_sum_3_game_norm', 0.00041132889523573697),
#  ('Contested Marks_prevous_year_mean', 0.00041110640380076876),
#  ('Total Points Scored_prevous_year_mean', 0.00041096627517060025),
#  ('Inside 50s_exponential_mean_3_round_norm', 0.00041087579684257776),
#  ('Marks_triang_mean_5_round_norm', 0.0004107234191682854),
#  ('Margin_shift_1', 0.00041040468096388495),
#  ('One Percenters_boxcar_sum_3_game_norm', 0.0004099942210252891),
#  ('Clangers_shift_3_game_norm', 0.00040996703599127817),
#  ('Behinds_boxcar_mean_5_round_norm', 0.0004093971367982127),
#  ('Contested Marks_exponential_mean_5_game_norm', 0.00040887514976249874),
#  ('Kicks_boxcar_sum_3_round_norm', 0.0004086634922363687),
#  ('Player Team Score_shift_1', 0.0004085675966230447),
#  ('Inside 50s_exponential_sum_5', 0.0004083755098639993),
#  ('Uncontested Possessions_boxcar_sum_3_round_norm', 0.00040784579863854635),
#  ('Uncontested Possessions_triang_mean_5_round_norm', 0.0004077483345959251),
#  ('Handballs_exponential_sum_3_game_norm', 0.00040763980260796783),
#  ('Hit Outs_cumulative_max', 0.0004073985046546848),
#  ('Contested Possessions_exponential_sum_3_round_norm',
#   0.00040738279863258056),
#  ('Frees_cumulative_max_game_norm', 0.00040667145850191465),
#  ('Rebounds_cumulative_max_game_norm', 0.00040630937901953065),
#  ('Tackles_shift_4_game_norm', 0.0004061230626445982),
#  ('Day of Year_shift_1_game_norm', 0.00040599076913309896),
#  ('Kicks_exponential_sum_5', 0.0004050439631777715),
#  ('Rebounds_triang_sum_5_game_norm', 0.00040492224634222694),
#  ('Handballs_shift_5_game_norm', 0.00040467763367212745),
#  ('Kicks_prevous_year_sum', 0.00040353575083520933),
#  ('Goal Assists_exponential_mean_5_round_norm', 0.0004031592402287505),
#  ('Margin_prevous_year_sum', 0.0004025712478696977),
#  ('Contested Possessions_exponential_sum_3_game_norm', 0.0004020530654855517),
#  ('Uncontested Possessions_exponential_sum_5', 0.00040198212176724543),
#  ('Midfield', 0.00040133726412507363),
#  ('One Percenters_exponential_mean_3_round_norm', 0.0004013266781957495),
#  ('Kicks_exponential_mean_3_round_norm', 0.0004005199729773949),
#  ('Handballs_shift_1', 0.00039999336645036074),
#  ('Clangers_shift_3_round_norm', 0.00039991580196725214),
#  ('Disposals_exponential_mean_3_round_norm', 0.0003997285906254039),
#  ('% Played_triang_sum_5', 0.0003990760814575152),
#  ('Uncontested Possessions_triang_mean_3_game_norm', 0.0003983601195187061),
#  ('Inside 50s_boxcar_mean_3_round_norm', 0.00039819707573070343),
#  ('Goals_prevous_year_mean_game_norm', 0.00039766673108181246),
#  ('Uncontested Possessions_shift_5_round_norm', 0.000397346401932624),
#  ('Inside 50s_shift_3_round_norm', 0.00039698557349770525),
#  ('Tackles_triang_mean_3_round_norm', 0.0003964744303526714),
#  ('Player Team Score_cumulative_sum', 0.00039617796963081536),
#  ('Frees_boxcar_sum_5_round_norm', 0.00039593702474374667),
#  ('Frees Against_boxcar_sum_5_game_norm', 0.0003954293084009872),
#  ('Tackles_cumulative_sum', 0.0003953261840299184),
#  ('Kicks_shift_5_game_norm', 0.00039524464811995094),
#  ('Day of Year_shift_3_round_norm', 0.0003949274290467939),
#  ('Uncontested Possessions_exponential_sum_3_game_norm',
#   0.0003944690341486326),
#  ('Day of Year_shift_5_round_norm', 0.0003934481655402417),
#  ('One Percenters_prevous_year_sum_round_norm', 0.00039326574621315074),
#  ('Player Team Score_prevous_year_sum', 0.0003928982100480568),
#  ('Inside 50s_shift_3_game_norm', 0.0003924140544439353),
#  ('Opponent Team Score_triang_sum_5_game_norm', 0.0003923853927738606),
#  ('Player Team Score_shift_4_game_norm', 0.0003918700258402885),
#  ('Contested Possessions_cumulative_sum', 0.00039099591405406415),
#  ('Kicks_exponential_sum_5_round_norm', 0.0003903805650934636),
#  ('Frees_triang_mean_5_round_norm', 0.00039030568438765275),
#  ('Disposals_prevous_year_sum_round_norm', 0.0003902629982310401),
#  ('Frees Against_cumulative_max_game_norm', 0.0003899208518641115),
#  ('Clearances_triang_mean_5_game_norm', 0.00038980500988463403),
#  ('Is Home Team', 0.00038972751355681435),
#  ('Rebounds_triang_mean_5_round_norm', 0.00038972026186048976),
#  ('Player Team Score_triang_sum_5_game_norm', 0.0003894860767289908),
#  ('rainfall_shift_1', 0.00038940015124845634),
#  ('One Percenters_shift_3_game_norm', 0.0003890636502795279),
#  ('Opponent Team Score_boxcar_sum_5', 0.0003889220735162569),
#  ('Rebounds_boxcar_mean_3_game_norm', 0.00038848148239424015),
#  ('Contested Possessions_triang_mean_3_game_norm', 0.0003883543753049175),
#  ('Frees Against_exponential_mean_3_game_norm', 0.00038758966121126297),
#  ('Contested Possessions_exponential_mean_3', 0.0003875784494250728),
#  ('Rebounds_shift_1_game_norm', 0.0003874175913907843),
#  ('Marks_triang_mean_3_round_norm', 0.0003872573685590925),
#  ('Kicks_exponential_sum_3_game_norm', 0.0003870580037077669),
#  ('Kicks_shift_5_round_norm', 0.0003868420947130961),
#  ('Total Points Scored_cumulative_sum', 0.0003861798310299493),
#  ('Uncontested Possessions_shift_3', 0.0003858021476425356),
#  ('Frees_exponential_sum_3_round_norm', 0.00038425235596036033),
#  ('Player Team Score_boxcar_sum_5_round_norm', 0.0003841818258474954),
#  ('Contested Possessions_prevous_year_sum', 0.00038416119842754425),
#  ('gameNumber_exponential_mean_3_round_norm', 0.00038369547760536057),
#  ('One Percenters_triang_mean_3_game_norm', 0.00038369057518533004),
#  ('Disposals_boxcar_mean_3_round_norm', 0.0003833128192295325),
#  ('Disposals_shift_4', 0.00038331134451230877),
#  ('Total Points Scored_boxcar_sum_5_game_norm', 0.00038268348333334116),
#  ('Kicks_triang_sum_5_game_norm', 0.0003822056087785906),
#  ('Frees_boxcar_sum_5_game_norm', 0.0003821207117814414),
#  ('Game Result_cumulative_sum_game_norm', 0.00038184071086607254),
#  ('Bounces_prevous_year_sum_round_norm', 0.00038182688757519643),
#  ('Total Points Scored_boxcar_mean_5_game_norm', 0.00038163827338309015),
#  ('Disposals_triang_sum_5_game_norm', 0.00038147445618164815),
#  ('Rebounds_shift_2_game_norm', 0.00038127064881402357),
#  ('Disposals_triang_mean_5_game_norm', 0.0003811865423678798),
#  ('Uncontested Possessions_exponential_sum_3_round_norm',
#   0.00038107036062648176),
#  ('Game Result_prevous_year_sum_game_norm', 0.00038088998609125583),
#  ('Opponent Team Score_boxcar_sum_3_round_norm', 0.0003804276737870618),
#  ('Inside 50s_triang_sum_5_round_norm', 0.000380291749940749),
#  ('Clearances_exponential_sum_5_game_norm', 0.0003800818506230388),
#  ('Bounces_cumulative_sum_game_norm', 0.0003800602631441155),
#  ('Disposals_exponential_mean_3_game_norm', 0.00037983479161045607),
#  ('Contested Possessions_shift_5_game_norm', 0.00037947814947663814),
#  ('gameNumber_triang_sum_5', 0.00037923190232381707),
#  ('Clangers_boxcar_sum_3_game_norm', 0.00037898114600545444),
#  ('Inside 50s_exponential_mean_5', 0.0003788575863112732),
#  ('Clangers_cumulative_sum', 0.00037868745819928445),
#  ('Uncontested Possessions_triang_sum_5_round_norm', 0.00037836159469155616),
#  ('Behinds_exponential_mean_5_game_norm', 0.0003781027233749536),
#  ('Start Time Hour', 0.00037737030053703447),
#  ('% Played_boxcar_mean_3', 0.00037685444817441634),
#  ('Clangers_shift_5_round_norm', 0.00037684048924845027),
#  ('Frees Against_triang_sum_5_game_norm', 0.00037645797874849666),
#  ('Uncontested Possessions_cumulative_min', 0.0003757158487334785),
#  ('Frees Against_triang_mean_5_round_norm', 0.0003756544515539742),
#  ('Frees_exponential_mean_3_game_norm', 0.0003752222135111654),
#  ('Rebounds_exponential_sum_3_game_norm', 0.0003751696649563824),
#  ('gameNumber_triang_mean_5', 0.0003751252113684086),
#  ('Opponent Team Score_triang_sum_5_round_norm', 0.00037510622790244745),
#  ('Hit Outs_prevous_year_sum_game_norm', 0.00037469067395486425),
#  ('Total Points Scored_shift_3_game_norm', 0.0003745324430917751),
#  ('% Played_shift_3', 0.0003742665239483099),
#  ('Kicks_triang_mean_3_round_norm', 0.0003741732076526654),
#  ('Opponent Team Score_exponential_sum_3_game_norm', 0.0003737016123697063),
#  ('Goal Assists_prevous_year_sum_round_norm', 0.0003735918773259217),
#  ('Inside 50s_shift_4_round_norm', 0.0003733966821738752),
#  ('Goals_cumulative_sum_game_norm', 0.00037319205109307774),
#  ('Rebounds_boxcar_mean_3_round_norm', 0.00037317601391531787),
#  ('Frees_triang_sum_5_game_norm', 0.00037291084171443633),
#  ('Uncontested Possessions_exponential_mean_3_round_norm',
#   0.00037273425155239377),
#  ('Kicks_triang_mean_3_game_norm', 0.00037248029411356733),
#  ('Rebounds_triang_sum_5_round_norm', 0.00037242386641648563),
#  ('Game Result_prevous_year_mean_round_norm', 0.0003718771431641133),
#  ('Contested Possessions_prevous_year_sum_round_norm', 0.0003714595594552064),
#  ('Marks Inside 50_cumulative_max_game_norm', 0.0003713788857009908),
#  ('Margin_shift_1_game_norm', 0.0003712901611062665),
#  ('Rebounds_exponential_mean_3_round_norm', 0.00037121798239564874),
#  ('Inside 50s_cumulative_sum', 0.0003712155674283173),
#  ('Disposals_exponential_mean_5', 0.0003710631735690198),
#  ('Margin_shift_4_game_norm', 0.00037058144695386084),
#  ('Hit Outs_prevous_year_mean_game_norm', 0.0003704062436155171),
#  ('Kicks_shift_4', 0.0003702222225025128),
#  ('Contested Marks_exponential_sum_5_round_norm', 0.0003699667963021631),
#  ('Handballs_exponential_mean_3', 0.0003699474480129151),
#  ('Contested Possessions_triang_mean_3_round_norm', 0.00036973240879070485),
#  ('Contested Possessions_triang_sum_5_round_norm', 0.00036923217893147656),
#  ('Goal Assists_exponential_sum_5_game_norm', 0.0003687428978043995),
#  ('Tackles_cumulative_min_game_norm', 0.0003677003566082262),
#  ('Marks_exponential_sum_3_round_norm', 0.000367577409449157),
#  ('Disposals_exponential_sum_3_game_norm', 0.0003673418100225861),
#  ('Frees_triang_sum_5_round_norm', 0.0003670762807453017),
#  ('Day of Year_shift_4_round_norm', 0.0003667745576505339),
#  ('Goal Assists_boxcar_mean_5_round_norm', 0.0003667243716851039),
#  ('Disposals_exponential_sum_5_game_norm', 0.00036616052403362084),
#  ('Kicks_triang_sum_3_game_norm', 0.0003660766372870201),
#  ('Total Points Scored_shift_1_round_norm', 0.0003650520551123116),
#  ('Rebounds_exponential_sum_3_round_norm', 0.0003646438340478122),
#  ('Kicks_exponential_sum_3', 0.0003643209581446507),
#  ('Rebounds_shift_3_round_norm', 0.00036402931745720726),
#  ('Disposals_prevous_year_sum', 0.0003638343156654793),
#  ('Game Result_prevous_year_mean', 0.0003632551323905496),
#  ('Disposals_exponential_mean_5_round_norm', 0.00036321803058731903),
#  ('Frees Against_exponential_sum_3_game_norm', 0.00036304559501224563),
#  ('Start Time Minute_shift_1_game_norm', 0.00036211750725541255),
#  ('Handballs_triang_mean_3_game_norm', 0.00036198385245838114),
#  ('Clangers_shift_4_game_norm', 0.00036173127648544257),
#  ('Rebounds_boxcar_sum_3_round_norm', 0.00036127377939847144),
#  ('Clangers_shift_4_round_norm', 0.0003609108594291161),
#  ('Disposals_triang_mean_5_round_norm', 0.00036089959062907226),
#  ('Marks_shift_5_round_norm', 0.0003606962429168397),
#  ('Frees_exponential_sum_3_game_norm', 0.0003602887669266348),
#  ('Player Team Score_exponential_sum_3_game_norm', 0.000360288218631736),
#  ('Clangers_triang_mean_3_game_norm', 0.00036026519823957696),
#  ('gameNumber_prevous_year_sum_round_norm', 0.00036013750270797514),
#  ('Total Points Scored_shift_2_round_norm', 0.00035996227208650396),
#  ('Contested Marks_exponential_mean_5_round_norm', 0.0003595874920033807),
#  ('Opponent Team Score_exponential_sum_3_round_norm', 0.0003594884124860627),
#  ('Clangers_boxcar_sum_3_round_norm', 0.0003594029300942028),
#  ('Clearances_boxcar_sum_3_round_norm', 0.00035917765961179896),
#  ('Hit Outs_cumulative_max_round_norm', 0.00035810399348523307),
#  ('Uncontested Possessions_boxcar_mean_5', 0.00035745659431660366),
#  ('Goal Assists_exponential_mean_5_game_norm', 0.0003571466539903046),
#  ('% Played_exponential_sum_3', 0.000357021002756491),
#  ('Uncontested Possessions_triang_sum_3_game_norm', 0.0003562966036403751),
#  ('Opponent Team Score_boxcar_mean_5_game_norm', 0.00035598104242489075),
#  ('Marks Inside 50_exponential_sum_5_game_norm', 0.0003558225829530935),
#  ('gameNumber_exponential_sum_3_round_norm', 0.0003556264017303716),
#  ('Clearances_boxcar_mean_3_game_norm', 0.00035558214106262936),
#  ('Opponent Team Score_exponential_mean_5_game_norm', 0.0003554745241099546),
#  ('Total Points Scored_prevous_year_mean_game_norm', 0.000355420169297972),
#  ('Hit Outs_shift_2_game_norm', 0.00035534840743338733),
#  ('Handballs_triang_sum_3_game_norm', 0.0003552807907277679),
#  ('Start Time Minute_shift_1_round_norm', 0.00035510315286644585),
#  ('Contested Possessions_triang_sum_3_game_norm', 0.00035488592756809133),
#  ('Inside 50s_boxcar_sum_3_game_norm', 0.0003542561942028549),
#  ('Kicks_exponential_sum_3_round_norm', 0.0003542442122139405),
#  ('Player Team Score_boxcar_sum_3_game_norm', 0.0003538494201410116),
#  ('Marks_shift_5_game_norm', 0.00035304598732972326),
#  ('Frees_exponential_mean_3_round_norm', 0.00035298024448523146),
#  ('rainfall_shift_2_round_norm', 0.00035264054915566743),
#  ('Marks Inside 50_exponential_mean_5_game_norm', 0.0003524392076445368),
#  ('Marks_triang_sum_3_round_norm', 0.000352022475061481),
#  ('Player Team Score_boxcar_sum_3_round_norm', 0.0003514374735887524),
#  ('Inside 50s_exponential_sum_3_round_norm', 0.0003514270031402443),
#  ('Inside 50s_triang_sum_3_game_norm', 0.0003513633791013828),
#  ('Kicks_triang_sum_5_round_norm', 0.00035079677804952347),
#  ('One Percenters_triang_sum_3_game_norm', 0.0003505123674012411),
#  ('Contested Marks_boxcar_mean_5_round_norm', 0.0003503127677232047),
#  ('Behinds_exponential_mean_5_round_norm', 0.0003501198637900463),
#  ('gameNumber_boxcar_sum_3', 0.0003493224177348622),
#  ('Opponent Team Score_boxcar_sum_3_game_norm', 0.000349172311101354),
#  ('One Percenters_shift_4_round_norm', 0.0003491501057021321),
#  ('Frees Against_boxcar_sum_5_round_norm', 0.0003491341100885784),
#  ('Behinds_prevous_year_sum_round_norm', 0.000349072613903616),
#  ('Behinds_boxcar_mean_5_game_norm', 0.0003488934329802691),
#  ('Weekday', 0.00034831690754606834),
#  ('Clearances_exponential_sum_5_round_norm', 0.0003481022018503075),
#  ('Tackles_triang_sum_3_game_norm', 0.0003480850128160604),
#  ('Contested Marks_boxcar_mean_5_game_norm', 0.0003480374041429901),
#  ('Rebounds_shift_2_round_norm', 0.000347404611000021),
#  ('Clearances_exponential_mean_5_game_norm', 0.0003468812707920739),
#  ('Contested Possessions_triang_sum_3_round_norm', 0.0003464338600898237),
#  ('% Played_cumulative_sum', 0.00034575137896159116),
#  ('Goal Assists_exponential_sum_5_round_norm', 0.000345168839220765),
#  ('Clearances_shift_3_round_norm', 0.0003451546453723004),
#  ('Marks_exponential_mean_3', 0.0003450706410804927),
#  ('Handballs_shift_2', 0.0003449109588494301),
#  ('Brownlow Votes_prevous_year_mean_round_norm', 0.00034472636468637193),
#  ('Rebounds_exponential_sum_5', 0.00034356756678810926),
#  ('Inside 50s_boxcar_sum_3_round_norm', 0.00034309599607637467),
#  ('Contested Marks_exponential_sum_5_game_norm', 0.000343090127369337),
#  ('rainfall_shift_3_round_norm', 0.000343074503140736),
#  ('Bounces_prevous_year_mean', 0.00034299179326927607),
#  ('gameNumber_triang_mean_3_round_norm', 0.0003426007082153195),
#  ('Uncontested Possessions_triang_mean_3_round_norm', 0.0003425842814770259),
#  ('Disposals_boxcar_sum_3_round_norm', 0.00034197818135189286),
#  ('One Percenters_shift_4_game_norm', 0.0003416050906201035),
#  ('Frees Against_triang_sum_5_round_norm', 0.00034103995375959833),
#  ('Disposals_triang_sum_3_game_norm', 0.0003409414589179174),
#  ('One Percenters_triang_mean_3_round_norm', 0.00034076138847071667),
#  ('Player Team Score_prevous_year_sum_round_norm', 0.0003404602345659476),
#  ('Contested Marks_prevous_year_sum_round_norm', 0.00034034758309851),
#  ('Total Points Scored_prevous_year_mean_round_norm', 0.0003403283029193013),
#  ('Rebounds_boxcar_sum_3_game_norm', 0.0003401320818422813),
#  ('Handballs_boxcar_mean_5', 0.00034006788635234617),
#  ('Opponent Team Score_boxcar_mean_5_round_norm', 0.0003399923043606312),
#  ('Clearances_shift_3_game_norm', 0.00033969159901302997),
#  ('Disposals_exponential_sum_5_round_norm', 0.00033966316731848326),
#  ('Rebounds_exponential_mean_3_game_norm', 0.0003394316403409094),
#  ('One Percenters_shift_5_round_norm', 0.000339391735897725),
#  ('Frees Against_exponential_sum_3_round_norm', 0.0003391180690890728),
#  ('Inside 50s_shift_4_game_norm', 0.0003386054204238323),
#  ('gameNumber_triang_sum_3_round_norm', 0.00033759385657301826),
#  ('Behinds_triang_mean_5_round_norm', 0.00033701384686801917),
#  ('Frees Against_exponential_mean_5', 0.00033698375840448365),
#  ('Rebounds_exponential_mean_5', 0.0003367015271996496),
#  ('Clearances_boxcar_mean_3_round_norm', 0.0003361581979739526),
#  ('Frees Against_cumulative_max_round_norm', 0.00033595791422726367),
#  ('Clangers_triang_sum_3_game_norm', 0.0003358716207244721),
#  ('Frees_cumulative_max_round_norm', 0.0003357134762745619),
#  ('Clangers_shift_5_game_norm', 0.0003356803315657337),
#  ('% Played_triang_mean_3', 0.0003356092097749814),
#  ('gameNumber_exponential_mean_3', 0.00033490206242718624),
#  ('Clearances_exponential_mean_5_round_norm', 0.0003348015230333692),
#  ('rainfall_shift_3', 0.00033475746263778375),
#  ('Clearances_triang_mean_5_round_norm', 0.0003346970694257699),
#  ('gameNumber_prevous_year_sum', 0.0003342860534518561),
#  ('gameNumber_cumulative_min_game_norm', 0.0003339521008704328),
#  ('Player Team Score_boxcar_mean_5_round_norm', 0.0003332716094741688),
#  ('Tackles_triang_sum_3_round_norm', 0.00033302130352788487),
#  ('Clearances_triang_sum_5_game_norm', 0.00033261793170231995),
#  ('Tackles_boxcar_mean_5', 0.00033260344664171835),
#  ('Start Time Minute_shift_2_game_norm', 0.0003325748688399174),
#  ('% Played_shift_4', 0.00033240507720274813),
#  ('Disposals_triang_sum_5_round_norm', 0.00033221150900985153),
#  ('Total Points Scored_shift_1_game_norm', 0.0003320652856750164),
#  ('Rebounds_triang_mean_3_game_norm', 0.0003315132586383345),
#  ('Marks Inside 50_boxcar_mean_5_round_norm', 0.000330091104455466),
#  ('Opponent Team Score_exponential_sum_5', 0.0003298779805945284),
#  ('% Played_prevous_year_sum_round_norm', 0.0003295414767528414),
#  ('Margin_shift_5_game_norm', 0.0003294947661452953),
#  ('gameNumber_boxcar_mean_3', 0.00032904960645951747),
#  ('Bounces_boxcar_mean_5_round_norm', 0.00032874497841928316),
#  ('Frees Against_exponential_mean_3_round_norm', 0.00032870839443860947),
#  ('Player Team Score_exponential_sum_5', 0.00032850257299481234),
#  ('Behinds_exponential_sum_5_game_norm', 0.0003280409004462753),
#  ('Clearances_exponential_mean_3_game_norm', 0.00032786509952586985),
#  ('Inside 50s_triang_mean_3_game_norm', 0.00032726951883140106),
#  ('Total Points Scored_boxcar_mean_5_round_norm', 0.0003272093911000213),
#  ('Uncontested Possessions_prevous_year_sum', 0.00032685533459110886),
#  ('Uncontested Possessions_triang_sum_3_round_norm', 0.0003267381522483184),
#  ('Contested Marks_triang_mean_5_game_norm', 0.00032616778539346964),
#  ('Uncontested Possessions_boxcar_sum_5', 0.0003260488304665975),
#  ('Marks_exponential_sum_3', 0.0003244285082611798),
#  ('Contested Possessions_shift_3', 0.00032429158085735445),
#  ('Clearances_boxcar_sum_3_game_norm', 0.0003242705450459546),
#  ('Clangers_triang_sum_3_round_norm', 0.0003242481554587234),
#  ('Tackles_shift_5_game_norm', 0.0003230211942977363),
#  ('Day of Year_shift_2_game_norm', 0.00032301155688278273),
#  ('Kicks_cumulative_sum', 0.0003223547221804342),
#  ('rainfall_shift_2', 0.0003222314768767216),
#  ('Marks Inside 50_triang_mean_5_game_norm', 0.0003221553681403003),
#  ('Contested Possessions_cumulative_min', 0.00032209160525272044),
#  ('Contested Possessions_exponential_sum_3', 0.000322030114546858),
#  ('Frees Against_boxcar_mean_3_game_norm', 0.00032195561752792334),
#  ('gameNumber_exponential_sum_3', 0.00032190183037068983),
#  ('Day of Year_shift_1', 0.0003216467736139155),
#  ('Clangers_exponential_mean_3', 0.0003215308693370381),
#  ('Disposals_triang_mean_3_round_norm', 0.0003213180520590309),
#  ('gameNumber_prevous_year_mean_round_norm', 0.00032101060862051915),
#  ('Disposals_boxcar_mean_5', 0.0003203457774630931),
#  ('Tackles_exponential_mean_3', 0.00032014612064736286),
#  ('Frees_exponential_mean_5', 0.0003196103268291125),
#  ('Rebounds_cumulative_sum', 0.000319239233440739),
#  ('Disposals_shift_5', 0.00031904223314011915),
#  ('Goal Assists_cumulative_max_game_norm', 0.00031890565201579056),
#  ('Uncontested Possessions_cumulative_sum', 0.0003188620419567671),
#  ('One Percenters_triang_sum_3_round_norm', 0.0003186184305237538),
#  ('Goal Assists_triang_mean_5_game_norm', 0.0003178430416641282),
#  ('Total Points Scored_prevous_year_sum_game_norm', 0.00031779674742446695),
#  ('Handballs_cumulative_max', 0.00031771161588142386),
#  ('Rebounds_triang_sum_3_game_norm', 0.0003173076085605542),
#  ...]
